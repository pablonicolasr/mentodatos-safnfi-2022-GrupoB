# %% [markdown]
# # Diplomatura en Ciencia de Datos, Aprendizaje Automático y sus Aplicaciones
#
# Edición 2022

# %%
#!pip install matplotlib==3.4

# %%
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
import nltk
import os

nltk.download("stopwords")
nltk.download("punkt")
nltk.download("wordnet")
nltk.download("omw-1.4")
nltk.download("averaged_perceptron_tagger")
nltk.download("universal_tagset")

# from google.colab import drive
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
from nltk.tag import pos_tag, map_tag

sns.set_context('talk')

np.set_printoptions(suppress=True)  # no usar notacion "e"
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\sheldon\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\sheldon\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\sheldon\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\sheldon\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\sheldon\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package universal_tagset to
# [nltk_data]     C:\Users\sheldon\AppData\Roaming\nltk_data...
# [nltk_data]   Package universal_tagset is already up-to-date!

# %% [markdown]
# # Sincronizamos Google Colaboratory con Google Drive

# %%
# Declaramos la ruta principal
# google_drive = "/content/gdrive"
# root_path = os.path.join(google_drive, "My Drive", "Colab Notebooks", "mentodatos")

# drive.mount(google_drive, force_remount = True)

# %%
# load dataset
df = pd.read_csv(os.path.join(os.getcwd(), "data", "news_dataset.csv"))

# %%
# dataset dimension
df.shape
# Out:
# (221513, 9)

# %%
# dataset information
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 221513 entries, 0 to 221512
# Data columns (total 9 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   id            221513 non-null  int64
#  1   ticker        221513 non-null  object
#  2   title         221513 non-null  object
#  3   category      221513 non-null  object
#  4   content       221505 non-null  object
#  5   release_date  221513 non-null  object
#  6   provider      221513 non-null  object
#  7   url           221513 non-null  object
#  8   article_id    221513 non-null  int64
# dtypes: int64(2), object(7)
# memory usage: 15.2+ MB

# %%
df.head(5)
# Out:
#        id ticker                                              title category  \
# 0  221515    NIO  Why Shares of Chinese Electric Car Maker NIO A...     news
# 1  221516    NIO  NIO only consumer gainer  Workhorse Group amon...     news
# 2  221517    NIO  NIO leads consumer gainers  Beyond Meat and Ma...     news
# 3  221518    NIO                  NIO  NVAX among premarket gainers     news
# 4  221519    NIO                  PLUG  NIO among premarket gainers     news
#
#                                              content release_date  \
# 0  What s happening\nShares of Chinese electric c...   2020-01-15
# 1  Gainers  NIO  NYSE NIO   7  \nLosers  MGP Ingr...   2020-01-18
# 2  Gainers  NIO  NYSE NIO   14   Village Farms In...   2020-01-15
# 3  Cemtrex  NASDAQ CETX   85  after FY results \n...   2020-01-15
# 4  aTyr Pharma  NASDAQ LIFE   63  on Kyorin Pharm...   2020-01-06
#
#           provider                                                url  \
# 0  The Motley Fool                             https://invst.ly/pigqi
# 1    Seeking Alpha                             https://invst.ly/pje9c
# 2    Seeking Alpha                             https://invst.ly/pifmv
# 3    Seeking Alpha                             https://invst.ly/picu8
# 4    Seeking Alpha  https://seekingalpha.com/news/3529772-plug-nio...
#
#    article_id
# 0     2060327
# 1     2062196
# 2     2060249
# 3     2060039
# 4     2053096

# %%
# statistical measures of the dataset
df.describe()
# Out:
#                   id    article_id
# count  221513.000000  2.215130e+05
# mean   332271.337872  9.510278e+07
# std     63945.826913  9.956825e+07
# min    221515.000000  6.690000e+02
# 25%    276893.000000  4.657470e+05
# 50%    332271.000000  2.038949e+06
# 75%    387650.000000  2.003073e+08
# max    443028.000000  2.005073e+08

# %%
# view column names
df.columns
# Out:
# Index(['id', 'ticker', 'title', 'category', 'content', 'release_date',
#        'provider', 'url', 'article_id'],
#       dtype='object')

# %%
# check for missing values
df.isnull().sum()
# Out:
# id              0
# ticker          0
# title           0
# category        0
# content         8
# release_date    0
# provider        0
# url             0
# article_id      0
# dtype: int64

# %%
df = df.dropna()
df.isnull().sum()
# Out:
# id              0
# ticker          0
# title           0
# category        0
# content         0
# release_date    0
# provider        0
# url             0
# article_id      0
# dtype: int64

# %%
provider_count = df["provider"].value_counts()\
    .reset_index()\
    .rename(columns={'index': 'provider', 'provider': 'frequency'})


for i, row in enumerate(provider_count.itertuples(), 1):
    print(row)
# Out:
# Pandas(Index=0, provider='Zacks Investment Research', frequency=88071)
# Pandas(Index=1, provider='Reuters', frequency=55095)
# Pandas(Index=2, provider='Investing.com', frequency=18466)
# Pandas(Index=3, provider='Seeking Alpha', frequency=12987)
# Pandas(Index=4, provider='Bloomberg', frequency=3422)
# Pandas(Index=5, provider='The Motley Fool', frequency=1251)
# Pandas(Index=6, provider='Nicholas Santiago', frequency=1065)
# Pandas(Index=7, provider='Gregory W. Harmon', frequency=972)
# Pandas(Index=8, provider='Estimize', frequency=962)
# Pandas(Index=9, provider='Ryan Mallory', frequency=905)
# Pandas(Index=10, provider='International Business Times', frequency=896)
# Pandas(Index=11, provider='iFOREX', frequency=765)
# Pandas(Index=12, provider='Dr. Duru', frequency=735)
# Pandas(Index=13, provider='CNBC', frequency=665)
# Pandas(Index=14, provider='Tim Knight', frequency=658)
# Pandas(Index=15, provider='Benzinga ', frequency=650)
# Pandas(Index=16, provider='Cointelegraph', frequency=643)
# Pandas(Index=17, provider='Harry Boxer', frequency=590)
# Pandas(Index=18, provider='Marvin Clark', frequency=546)
# Pandas(Index=19, provider='LFB Forex', frequency=544)
# Pandas(Index=20, provider='Cryptovest', frequency=515)
# Pandas(Index=21, provider='Pinchas Cohen/Investing.com', frequency=504)
# Pandas(Index=22, provider='Binary Options Strategy', frequency=465)
# Pandas(Index=23, provider='Brian Gilmartin', frequency=457)
# Pandas(Index=24, provider='Haris Anwar/Investing.com', frequency=457)
# Pandas(Index=25, provider='Edison', frequency=439)
# Pandas(Index=26, provider='Business Insider', frequency=410)
# Pandas(Index=27, provider='Marc Chandler', frequency=399)
# Pandas(Index=28, provider='MarketWatch', frequency=398)
# Pandas(Index=29, provider='MetalMiner', frequency=394)
# Pandas(Index=30, provider='AvaTrade', frequency=390)
# Pandas(Index=31, provider='JJ Kinahan', frequency=359)
# Pandas(Index=32, provider='Kenny Fisher', frequency=329)
# Pandas(Index=33, provider='Dividend Yield', frequency=324)
# Pandas(Index=34, provider='Charles Sizemore', frequency=314)
# Pandas(Index=35, provider='Danske Markets', frequency=311)
# Pandas(Index=36, provider='Jeff Miller', frequency=309)
# Pandas(Index=37, provider='Michael Kramer', frequency=305)
# Pandas(Index=38, provider='Trade The News', frequency=305)
# Pandas(Index=39, provider='Doug Short', frequency=301)
# Pandas(Index=40, provider='Midnight Trader', frequency=279)
# Pandas(Index=41, provider='Saxo Bank', frequency=270)
# Pandas(Index=42, provider='IFC Markets', frequency=267)
# Pandas(Index=43, provider='The Gold Report', frequency=259)
# Pandas(Index=44, provider='Frank Holmes', frequency=256)
# Pandas(Index=45, provider='John Nyaradi', frequency=254)
# Pandas(Index=46, provider='Gareth Soloway', frequency=253)
# Pandas(Index=47, provider='Warrior Trading', frequency=252)
# Pandas(Index=48, provider='Steve Miller', frequency=244)
# Pandas(Index=49, provider='The Night Owl Trader', frequency=241)
# Pandas(Index=50, provider='David Trainer', frequency=238)
# Pandas(Index=51, provider='James Picerno', frequency=233)
# Pandas(Index=52, provider='Petros Steriotis', frequency=226)
# Pandas(Index=53, provider='247wallst', frequency=219)
# Pandas(Index=54, provider='Wall Street Daily', frequency=215)
# Pandas(Index=55, provider='Michael T. Snyder', frequency=213)
# Pandas(Index=56, provider='Modest Money', frequency=212)
# Pandas(Index=57, provider='Brett Owens', frequency=199)
# Pandas(Index=58, provider='Danny Riley', frequency=198)
# Pandas(Index=59, provider='Louis Basenese', frequency=196)
# Pandas(Index=60, provider='Yale Bock', frequency=194)
# Pandas(Index=61, provider='ICM Brokers', frequency=194)
# Pandas(Index=62, provider='Sober Look', frequency=186)
# Pandas(Index=63, provider="Schaeffer's Investment Research", frequency=184)
# Pandas(Index=64, provider='Double Dividend Stocks', frequency=182)
# Pandas(Index=65, provider='Anthony M. Cherniawski', frequency=180)
# Pandas(Index=66, provider='Lance Roberts', frequency=177)
# Pandas(Index=67, provider='Boris Schlossberg', frequency=174)
# Pandas(Index=68, provider='Chuck Carnevale', frequency=171)
# Pandas(Index=69, provider='Kathy Lien', frequency=170)
# Pandas(Index=70, provider='Phil Flynn', frequency=167)
# Pandas(Index=71, provider='IG', frequency=164)
# Pandas(Index=72, provider='GCI Financial', frequency=164)
# Pandas(Index=73, provider='London Capital Group', frequency=159)
# Pandas(Index=74, provider='Cam Hui', frequency=154)
# Pandas(Index=75, provider='Investment U', frequency=152)
# Pandas(Index=76, provider='Clement Thibault/Investing.com ', frequency=151)
# Pandas(Index=77, provider='Gary Gordon', frequency=150)
# Pandas(Index=78, provider='ETF Daily News', frequency=148)
# Pandas(Index=79, provider='EWM Interactive', frequency=148)
# Pandas(Index=80, provider='The National Bank of Canada', frequency=145)
# Pandas(Index=81, provider='Contextuall', frequency=139)
# Pandas(Index=82, provider='Dean Popplewell', frequency=138)
# Pandas(Index=83, provider='Rick Ackerman', frequency=136)
# Pandas(Index=84, provider='Alex Newman', frequency=136)
# Pandas(Index=85, provider='Trade12', frequency=135)
# Pandas(Index=86, provider='Ophir Gottlieb', frequency=134)
# Pandas(Index=87, provider='Jack Chan', frequency=134)
# Pandas(Index=88, provider='Ipek Ozkardeskaya', frequency=133)
# Pandas(Index=89, provider='Mike (Mish) Shedlock', frequency=130)
# Pandas(Index=90, provider='Commodity Trade Mantra', frequency=127)
# Pandas(Index=91, provider='Warren Bevan', frequency=127)
# Pandas(Index=92, provider='Chris Kimble', frequency=124)
# Pandas(Index=93, provider='The Energy Report', frequency=121)
# Pandas(Index=94, provider='ValueWalk', frequency=121)
# Pandas(Index=95, provider='Henry Liu', frequency=119)
# Pandas(Index=96, provider='Finbox io', frequency=119)
# Pandas(Index=97, provider='AllAboutAlpha', frequency=118)
# Pandas(Index=98, provider='Ticker.tv News', frequency=118)
# Pandas(Index=99, provider='Mark Mead Baillie', frequency=117)
# Pandas(Index=100, provider='Ed Moya', frequency=116)
# Pandas(Index=101, provider='Paul Rejczak', frequency=110)
# Pandas(Index=102, provider='Blaine Rollins', frequency=109)
# Pandas(Index=103, provider='Scott Martindale', frequency=107)
# Pandas(Index=104, provider='Dailyfx', frequency=107)
# Pandas(Index=105, provider='Simon Lack', frequency=106)
# Pandas(Index=106, provider='Mitchell Clark', frequency=106)
# Pandas(Index=107, provider='ZIFX.com', frequency=105)
# Pandas(Index=108, provider='F.A.S.T. Graphs', frequency=103)
# Pandas(Index=109, provider='Mati Greenspan', frequency=103)
# Pandas(Index=110, provider='Matthew Weller', frequency=102)
# Pandas(Index=111, provider='Keith Fitz-Gerald', frequency=102)
# Pandas(Index=112, provider='David I. Kranzler', frequency=101)
# Pandas(Index=113, provider='Jeremy Cook', frequency=101)
# Pandas(Index=114, provider='Anna Coulling', frequency=99)
# Pandas(Index=115, provider='Mike Paulenoff', frequency=96)
# Pandas(Index=116, provider='PipHut', frequency=96)
# Pandas(Index=117, provider='Michael Foster', frequency=94)
# Pandas(Index=118, provider='EconMatters', frequency=93)
# Pandas(Index=119, provider='Joshua Rodriguez', frequency=90)
# Pandas(Index=120, provider='Craig Erlam', frequency=89)
# Pandas(Index=121, provider='Sarah Roden', frequency=89)
# Pandas(Index=122, provider='Easy Forex', frequency=89)
# Pandas(Index=123, provider='StreetAuthority', frequency=86)
# Pandas(Index=124, provider='Alhambra Investment Partners, LLC', frequency=85)
# Pandas(Index=125, provider='AceTrader', frequency=84)
# Pandas(Index=126, provider='Blog of HORAN Capital Advisors', frequency=83)
# Pandas(Index=127, provider='Michael Ashton', frequency=82)
# Pandas(Index=128, provider='Jack Steiman', frequency=81)
# Pandas(Index=129, provider='Richard Rhodes', frequency=80)
# Pandas(Index=130, provider='Mingze Wu', frequency=79)
# Pandas(Index=131, provider='Forexyard', frequency=79)
# Pandas(Index=132, provider='Jan Skoyles', frequency=79)
# Pandas(Index=133, provider='Brian Trumbore', frequency=76)
# Pandas(Index=134, provider='Joseph L. Shaefer', frequency=76)
# Pandas(Index=135, provider="Philippe d'Arvisenet", frequency=75)
# Pandas(Index=136, provider='ActionForex', frequency=74)
# Pandas(Index=137, provider='Michael Lombardi', frequency=74)
# Pandas(Index=138, provider='Benzinga', frequency=73)
# Pandas(Index=139, provider='Myriad Equity', frequency=72)
# Pandas(Index=140, provider='Ed Yardeni', frequency=72)
# Pandas(Index=141, provider='David Brown', frequency=70)
# Pandas(Index=142, provider='Forex4you', frequency=69)
# Pandas(Index=143, provider='CoinDesk', frequency=69)
# Pandas(Index=144, provider='XM Group', frequency=69)
# Pandas(Index=145, provider='Stuart McPhee', frequency=68)
# Pandas(Index=146, provider='Phoenix Capital Research', frequency=68)
# Pandas(Index=147, provider='Brian Bollinger', frequency=68)
# Pandas(Index=148, provider='Carly Forster', frequency=68)
# Pandas(Index=149, provider='FOREX.com', frequency=67)
# Pandas(Index=150, provider='Talking Forex', frequency=67)
# Pandas(Index=151, provider='Stephen Innes', frequency=67)
# Pandas(Index=152, provider='Hale Stewart', frequency=67)
# Pandas(Index=153, provider='Uri Gruenbaum', frequency=66)
# Pandas(Index=154, provider='David Dyer', frequency=66)
# Pandas(Index=155, provider='George Leong', frequency=65)
# Pandas(Index=156, provider='Jesse Cohen/Investing.com', frequency=65)
# Pandas(Index=157, provider='David Fabian', frequency=65)
# Pandas(Index=158, provider='YouTradeFX', frequency=64)
# Pandas(Index=159, provider='Keagan York', frequency=63)
# Pandas(Index=160, provider='LiteForex', frequency=63)
# Pandas(Index=161, provider='Robert B. Reich', frequency=63)
# Pandas(Index=162, provider='Ara Zohrabian', frequency=63)
# Pandas(Index=163, provider='Chris Vermeulen', frequency=63)
# Pandas(Index=164, provider='Kevin Flynn', frequency=63)
# Pandas(Index=165, provider='Candy Matheson', frequency=62)
# Pandas(Index=166, provider='Jeb Handwerger', frequency=61)
# Pandas(Index=167, provider='Chris Ciovacco', frequency=61)
# Pandas(Index=168, provider='Stefan Gleason', frequency=60)
# Pandas(Index=169, provider='David Kass', frequency=60)
# Pandas(Index=170, provider='David Merkel', frequency=59)
# Pandas(Index=171, provider='Littlefish FX', frequency=59)
# Pandas(Index=172, provider='Wade Slome', frequency=59)
# Pandas(Index=173, provider='Ivaylo Ivanhoff', frequency=58)
# Pandas(Index=174, provider='Dan Flynn', frequency=58)
# Pandas(Index=175, provider='Larry Doyle', frequency=57)
# Pandas(Index=176, provider='Mercenary Trader', frequency=56)
# Pandas(Index=177, provider='Alexandros Yfantis', frequency=55)
# Pandas(Index=178, provider='Money Show', frequency=55)
# Pandas(Index=179, provider='Steve St. Angelo', frequency=55)
# Pandas(Index=180, provider='Thinknum', frequency=53)
# Pandas(Index=181, provider='InvestCorrectly', frequency=53)
# Pandas(Index=182, provider='MarketBeat.com', frequency=52)
# Pandas(Index=183, provider='Andrew Robinson', frequency=52)
# Pandas(Index=184, provider='Scott Krisiloff', frequency=51)
# Pandas(Index=185, provider='Steven Hansen', frequency=51)
# Pandas(Index=186, provider='Tech Talk', frequency=51)
# Pandas(Index=187, provider='Brenda Jubin', frequency=51)
# Pandas(Index=188, provider='David Kotok', frequency=50)
# Pandas(Index=189, provider='Steve Hach', frequency=50)
# Pandas(Index=190, provider='ForexTime', frequency=50)
# Pandas(Index=191, provider='Bob Lang', frequency=49)
# Pandas(Index=192, provider='OptionsClick', frequency=49)
# Pandas(Index=193, provider='FSM News', frequency=49)
# Pandas(Index=194, provider='Stewart Thomson', frequency=47)
# Pandas(Index=195, provider='Ashraf Laidi', frequency=47)
# Pandas(Index=196, provider='Scott Matusow', frequency=47)
# Pandas(Index=197, provider='Matt Simpson', frequency=47)
# Pandas(Index=198, provider='Barani Krishnan/Investing.com', frequency=47)
# Pandas(Index=199, provider='Gregor Horvat', frequency=47)
# Pandas(Index=200, provider='Tiho Brkan', frequency=45)
# Pandas(Index=201, provider='Ellen R. Wald, Ph.D.', frequency=45)
# Pandas(Index=202, provider='Kiana Danial', frequency=44)
# Pandas(Index=203, provider="Mark O'Byrne", frequency=43)
# Pandas(Index=204, provider='MrTopStep', frequency=42)
# Pandas(Index=205, provider='Jani Ziedins', frequency=42)
# Pandas(Index=206, provider='Jeffrey Halley', frequency=41)
# Pandas(Index=207, provider='Frank Kollar', frequency=41)
# Pandas(Index=208, provider='Alexander Kuptsikevich', frequency=41)
# Pandas(Index=209, provider='Tommy Humphreys', frequency=41)
# Pandas(Index=210, provider='TipRanks', frequency=41)
# Pandas(Index=211, provider='GoldMoney News Desk', frequency=40)
# Pandas(Index=212, provider='James Chen', frequency=40)
# Pandas(Index=213, provider='RealVision', frequency=40)
# Pandas(Index=214, provider='BB Finance Blog', frequency=39)
# Pandas(Index=215, provider='Gary Tanashian', frequency=39)
# Pandas(Index=216, provider='ICN.com', frequency=39)
# Pandas(Index=217, provider='Ivan Delgado', frequency=39)
# Pandas(Index=218, provider='John Aziz', frequency=39)
# Pandas(Index=219, provider='Elliott Wave Forecast', frequency=38)
# Pandas(Index=220, provider='IronFX Strategy Team', frequency=38)
# Pandas(Index=221, provider='Kurt Cobb', frequency=38)
# Pandas(Index=222, provider='Dr. Alan Ellman', frequency=38)
# Pandas(Index=223, provider='Ivan Kitov', frequency=38)
# Pandas(Index=224, provider='Ed Dolan', frequency=37)
# Pandas(Index=225, provider='Alan Bradley', frequency=37)
# Pandas(Index=226, provider='Ben Reynolds', frequency=36)
# Pandas(Index=227, provider='Karim Rahemtulla', frequency=36)
# Pandas(Index=228, provider='trade 12', frequency=36)
# Pandas(Index=229, provider='TFI Markets', frequency=36)
# Pandas(Index=230, provider='Todd Sullivan', frequency=35)
# Pandas(Index=231, provider='Spread Betting', frequency=35)
# Pandas(Index=232, provider='Jay Kaeppel', frequency=35)
# Pandas(Index=233, provider='eFXnews', frequency=34)
# Pandas(Index=234, provider='Bruce Krasting', frequency=34)
# Pandas(Index=235, provider='Alan Gula', frequency=34)
# Pandas(Index=236, provider='Jim Makos', frequency=33)
# Pandas(Index=237, provider='Abhijit Sen', frequency=33)
# Pandas(Index=238, provider='LiteForex Europe', frequency=33)
# Pandas(Index=239, provider='Mark Lundeen', frequency=33)
# Pandas(Index=240, provider='Clif Droke', frequency=33)
# Pandas(Index=241, provider='Charles Hugh Smith', frequency=32)
# Pandas(Index=242, provider='Deron Wagner', frequency=32)
# Pandas(Index=243, provider='GO Markets', frequency=32)
# Pandas(Index=244, provider='Francis Gaskins', frequency=31)
# Pandas(Index=245, provider='John Rubino', frequency=31)
# Pandas(Index=246, provider='Viktor Shpakovsky', frequency=31)
# Pandas(Index=247, provider='Adam Hamilton', frequency=31)
# Pandas(Index=248, provider='StockTradingToGo', frequency=31)
# Pandas(Index=249, provider='Alfonso Esparza', frequency=30)
# Pandas(Index=250, provider='Kay Kim', frequency=30)
# Pandas(Index=251, provider='Jenny Rebekka', frequency=30)
# Pandas(Index=252, provider='Marcus Holland', frequency=29)
# Pandas(Index=253, provider='Harry Dent', frequency=28)
# Pandas(Index=254, provider='FX Street', frequency=28)
# Pandas(Index=255, provider='Fiona Cincotta', frequency=28)
# Pandas(Index=256, provider="Scott's Investments", frequency=28)
# Pandas(Index=257, provider='Samuel Rae', frequency=28)
# Pandas(Index=258, provider='Jesse Felder', frequency=27)
# Pandas(Index=259, provider='Emre Deliveli', frequency=27)
# Pandas(Index=260, provider='Arkadiusz Sieron', frequency=27)
# Pandas(Index=261, provider='Frank Zorrilla', frequency=26)
# Pandas(Index=262, provider='Markus Gabel', frequency=26)
# Pandas(Index=263, provider='PikerTrader', frequency=26)
# Pandas(Index=264, provider='Saj Karsan', frequency=26)
# Pandas(Index=265, provider='Erik Swarts', frequency=26)
# Pandas(Index=266, provider='TD Ameritrade', frequency=25)
# Pandas(Index=267, provider='Vitaliy Katsenelson', frequency=25)
# Pandas(Index=268, provider='David M. Frank', frequency=25)
# Pandas(Index=269, provider='Euro Pacific', frequency=25)
# Pandas(Index=270, provider='Justin Smyth', frequency=25)
# Pandas(Index=271, provider='Dr. Duke', frequency=24)
# Pandas(Index=272, provider='Matthew Bradbard', frequency=24)
# Pandas(Index=273, provider='Kyle Guske II', frequency=24)
# Pandas(Index=274, provider='Tim Shirata', frequency=24)
# Pandas(Index=275, provider='Aswath Damodaran', frequency=24)
# Pandas(Index=276, provider='Gail Tverberg', frequency=23)
# Pandas(Index=277, provider='Michael Pento', frequency=23)
# Pandas(Index=278, provider='Guy S. Ortmann, CMT', frequency=23)
# Pandas(Index=279, provider='CapitalCube', frequency=23)
# Pandas(Index=280, provider='Tanzeel Akhtar/Investing.com', frequency=23)
# Pandas(Index=281, provider='ORBEX', frequency=23)
# Pandas(Index=282, provider='ecPulse', frequency=23)
# Pandas(Index=283, provider='Richard Shaw', frequency=23)
# Pandas(Index=284, provider='Sol Palha', frequency=22)
# Pandas(Index=285, provider='OilPrice.com', frequency=22)
# Pandas(Index=286, provider='Jae Jun', frequency=22)
# Pandas(Index=287, provider='Kevin Davitt', frequency=22)
# Pandas(Index=288, provider='Jay Hawk', frequency=22)
# Pandas(Index=289, provider='Urban Carmel', frequency=21)
# Pandas(Index=290, provider='Scott Fearon', frequency=21)
# Pandas(Index=291, provider='TradingBanks', frequency=21)
# Pandas(Index=292, provider='Faizan Raza', frequency=21)
# Pandas(Index=293, provider='CommodityOnline', frequency=21)
# Pandas(Index=294, provider='Bill Poulos', frequency=21)
# Pandas(Index=295, provider='Bondsquawk', frequency=21)
# Pandas(Index=296, provider='Ed Anderson', frequency=21)
# Pandas(Index=297, provider='Stephen McBride', frequency=20)
# Pandas(Index=298, provider='Declan Fallon', frequency=20)
# Pandas(Index=299, provider='Abigail Doolittle', frequency=20)
# Pandas(Index=300, provider='BL', frequency=20)
# Pandas(Index=301, provider='Baskin Financial Blog', frequency=20)
# Pandas(Index=302, provider='Jennifer Lynn', frequency=20)
# Pandas(Index=303, provider='Sinisa Persic, CMT', frequency=19)
# Pandas(Index=304, provider='Bitcoinist', frequency=19)
# Pandas(Index=305, provider='Charles Biderman', frequency=19)
# Pandas(Index=306, provider='CNA Finance', frequency=19)
# Pandas(Index=307, provider='George Liu', frequency=19)
# Pandas(Index=308, provider='Andrew Thrasher', frequency=19)
# Pandas(Index=309, provider='Pater Tenebrarum', frequency=19)
# Pandas(Index=310, provider='Andrew Nyquist', frequency=19)
# Pandas(Index=311, provider='ETF Prophet', frequency=19)
# Pandas(Index=312, provider='Richard Mills', frequency=19)
# Pandas(Index=313, provider='Syncubate', frequency=18)
# Pandas(Index=314, provider='Lorenzo Riccio', frequency=18)
# Pandas(Index=315, provider='Cash Back Forex', frequency=18)
# Pandas(Index=316, provider='Dmitry Zeland', frequency=18)
# Pandas(Index=317, provider='FinanceMagnates', frequency=18)
# Pandas(Index=318, provider='Sean Mason, SmallCapPower.com', frequency=18)
# Pandas(Index=319, provider='UFXMarkets', frequency=17)
# Pandas(Index=320, provider='Chris Weston', frequency=17)
# Pandas(Index=321, provider='Naeem Aslam', frequency=17)
# Pandas(Index=322, provider='Panayiotis Miltiadous', frequency=17)
# Pandas(Index=323, provider='Robert Ross', frequency=17)
# Pandas(Index=324, provider='Blue Harbinger', frequency=17)
# Pandas(Index=325, provider='Igor Rakhmanov', frequency=17)
# Pandas(Index=326, provider='David Tablish', frequency=17)
# Pandas(Index=327, provider='Gary Christenson', frequency=17)
# Pandas(Index=328, provider='GoldTradingExperts.com', frequency=16)
# Pandas(Index=329, provider="Brenda O'Farrell/Investing.com", frequency=16)
# Pandas(Index=330, provider='Ryan Jordan', frequency=16)
# Pandas(Index=331, provider='Ian Copsey', frequency=16)
# Pandas(Index=332, provider='Trader Moe', frequency=16)
# Pandas(Index=333, provider='Adem Tumerkan', frequency=16)
# Pandas(Index=334, provider='Macro and Cheese', frequency=15)
# Pandas(Index=335, provider='Dave Fry', frequency=15)
# Pandas(Index=336, provider='Tim Ord', frequency=15)
# Pandas(Index=337, provider='Paban Pandey', frequency=15)
# Pandas(Index=338, provider='Atma Business Blog', frequency=15)
# Pandas(Index=339, provider='Epstein Research', frequency=15)
# Pandas(Index=340, provider='Jesse Boskoff', frequency=15)
# Pandas(Index=341, provider='Ron Hiram', frequency=15)
# Pandas(Index=342, provider='John Mylant', frequency=15)
# Pandas(Index=343, provider='Jordan Roy-Byrne, CMT', frequency=15)
# Pandas(Index=344, provider='Doug Eberhardt', frequency=15)
# Pandas(Index=345, provider='Philip Davis', frequency=15)
# Pandas(Index=346, provider='FIBO Group', frequency=14)
# Pandas(Index=347, provider='Peter Morici', frequency=14)
# Pandas(Index=348, provider='Andre Gratian', frequency=14)
# Pandas(Index=349, provider='Scott Barkley', frequency=14)
# Pandas(Index=350, provider='Steve Saville', frequency=14)
# Pandas(Index=351, provider='Helen Rush', frequency=14)
# Pandas(Index=352, provider='Keith Weiner', frequency=14)
# Pandas(Index=353, provider='Gary Hunt', frequency=14)
# Pandas(Index=354, provider='Eric Falkenstein', frequency=14)
# Pandas(Index=355, provider='Vance Harwood', frequency=14)
# Pandas(Index=356, provider='Macro Man', frequency=13)
# Pandas(Index=357, provider='Stock Option Assassin', frequency=13)
# Pandas(Index=358, provider='Stocks on Wall Street', frequency=13)
# Pandas(Index=359, provider='Matthew Carr', frequency=13)
# Pandas(Index=360, provider='Michael Gouvalaris', frequency=13)
# Pandas(Index=361, provider='Jake Huneycutt', frequency=13)
# Pandas(Index=362, provider='Mark Avis', frequency=13)
# Pandas(Index=363, provider='Fabius Maximus', frequency=13)
# Pandas(Index=364, provider='Andrew Dovey', frequency=13)
# Pandas(Index=365, provider='Sam McBride', frequency=13)
# Pandas(Index=366, provider='The Non-Consensus', frequency=13)
# Pandas(Index=367, provider='Patrick MontesDeOca', frequency=13)
# Pandas(Index=368, provider='Aviv N. Shapiro', frequency=13)
# Pandas(Index=369, provider='Dane Williams', frequency=13)
# Pandas(Index=370, provider='Nicholas Maithya', frequency=12)
# Pandas(Index=371, provider='T. Marc Schober', frequency=12)
# Pandas(Index=372, provider='Masterforex-V', frequency=12)
# Pandas(Index=373, provider='J.W. Jones', frequency=12)
# Pandas(Index=374, provider='Terry Tran', frequency=12)
# Pandas(Index=375, provider='James Hyerczyk', frequency=12)
# Pandas(Index=376, provider='Troy Bombardia', frequency=12)
# Pandas(Index=377, provider='High Chart Patterns', frequency=12)
# Pandas(Index=378, provider='Robert Williams', frequency=12)
# Pandas(Index=379, provider='Michael Panzner', frequency=11)
# Pandas(Index=380, provider='Thomas J. Feeney', frequency=11)
# Pandas(Index=381, provider='Bill Luby', frequency=11)
# Pandas(Index=382, provider='Martin Kay', frequency=11)
# Pandas(Index=383, provider='Andrew MacKillop', frequency=11)
# Pandas(Index=384, provider='4XP', frequency=11)
# Pandas(Index=385, provider='Anni V_', frequency=11)
# Pandas(Index=386, provider='Bill Witherell', frequency=11)
# Pandas(Index=387, provider='António Costa', frequency=11)
# Pandas(Index=388, provider='BeInCrypto', frequency=11)
# Pandas(Index=389, provider='FxPro London', frequency=11)
# Pandas(Index=390, provider='Joe Donohue', frequency=11)
# Pandas(Index=391, provider='Tony Daltorio', frequency=11)
# Pandas(Index=392, provider='Avi Gilburt', frequency=11)
# Pandas(Index=393, provider='Craig Adeyanju', frequency=11)
# Pandas(Index=394, provider='Charley Blaine/Investing.com', frequency=10)
# Pandas(Index=395, provider='InTheMoneyStocks.com', frequency=10)
# Pandas(Index=396, provider='Will Bancroft', frequency=10)
# Pandas(Index=397, provider='Marty Biancuzzo', frequency=10)
# Pandas(Index=398, provider='Lara Iriarte', frequency=10)
# Pandas(Index=399, provider='Michele Schneider', frequency=10)
# Pandas(Index=400, provider='Rajoo C', frequency=10)
# Pandas(Index=401, provider='Michael Pettis', frequency=10)
# Pandas(Index=402, provider='Al Brooks', frequency=10)
# Pandas(Index=403, provider='Eric De Groot', frequency=10)
# Pandas(Index=404, provider='Shailesh Kumar', frequency=10)
# Pandas(Index=405, provider='Elliott Morss', frequency=9)
# Pandas(Index=406, provider='Crowdability', frequency=9)
# Pandas(Index=407, provider='Rodrigo Corrêa da Costa', frequency=9)
# Pandas(Index=408, provider='John Slater', frequency=9)
# Pandas(Index=409, provider='Peter T. Treadway', frequency=9)
# Pandas(Index=410, provider='Jill Mislinski', frequency=9)
# Pandas(Index=411, provider='FXDD', frequency=9)
# Pandas(Index=412, provider='Ben Myers', frequency=9)
# Pandas(Index=413, provider='Verified Investing', frequency=9)
# Pandas(Index=414, provider='AMarkets Company', frequency=9)
# Pandas(Index=415, provider='Darryl Robert Schoon', frequency=9)
# Pandas(Index=416, provider='MyFXspot research', frequency=9)
# Pandas(Index=417, provider='Arnaldo Luiz Correa', frequency=9)
# Pandas(Index=418, provider='Bell Ringers/Investing.com ', frequency=9)
# Pandas(Index=419, provider='Peter Brandt', frequency=9)
# Pandas(Index=420, provider='Ashish K Nayak', frequency=8)
# Pandas(Index=421, provider='Christopher Grosvenor, CMT', frequency=8)
# Pandas(Index=422, provider='Taki Tsaklanos', frequency=8)
# Pandas(Index=423, provider='Kiran Shroff', frequency=8)
# Pandas(Index=424, provider='Dr. Jeffrey Lewis', frequency=8)
# Pandas(Index=425, provider='Halal Traders', frequency=8)
# Pandas(Index=426, provider='Paul Farrugia', frequency=8)
# Pandas(Index=427, provider='David Koh', frequency=8)
# Pandas(Index=428, provider='Rakuten Sec Australia', frequency=8)
# Pandas(Index=429, provider='Joe Perry', frequency=8)
# Pandas(Index=430, provider='First Binary Option Service', frequency=8)
# Pandas(Index=431, provider='anyoption', frequency=8)
# Pandas(Index=432, provider='JFD Team', frequency=8)
# Pandas(Index=433, provider='ING Economic and Financial Analysis', frequency=7)
# Pandas(Index=434, provider='Hannah Wood', frequency=7)
# Pandas(Index=435, provider='Sayat Kartabayev', frequency=7)
# Pandas(Index=436, provider='Michael Noonan', frequency=7)
# Pandas(Index=437, provider='Nick Mastrandrea', frequency=7)
# Pandas(Index=438, provider='Monty Guild', frequency=7)
# Pandas(Index=439, provider='Swissquote Bank Ltd', frequency=7)
# Pandas(Index=440, provider='Helix Investment Management', frequency=7)
# Pandas(Index=441, provider='Bill Holter', frequency=7)
# Pandas(Index=442, provider='David Chapman', frequency=7)
# Pandas(Index=443, provider='Felipe Potes', frequency=7)
# Pandas(Index=444, provider='Tory Enerson', frequency=7)
# Pandas(Index=445, provider='Barry Ferguson', frequency=7)
# Pandas(Index=446, provider='Tom Luongo', frequency=7)
# Pandas(Index=447, provider='Amram Margalit', frequency=7)
# Pandas(Index=448, provider='Scott Wright', frequency=7)
# Pandas(Index=449, provider='Neal Gilbert', frequency=7)
# Pandas(Index=450, provider='Jason Martin/Investing.com', frequency=7)
# Pandas(Index=451, provider='Scandinavian Capital Markets', frequency=6)
# Pandas(Index=452, provider='FX Recommends', frequency=6)
# Pandas(Index=453, provider='Adam Grimes', frequency=6)
# Pandas(Index=454, provider='Euronews', frequency=6)
# Pandas(Index=455, provider='J. Frank Sigerson', frequency=6)
# Pandas(Index=456, provider='Portfolio Cafe', frequency=6)
# Pandas(Index=457, provider='TechniTrader Stock Market Education', frequency=6)
# Pandas(Index=458, provider='Jesse Colombo', frequency=6)
# Pandas(Index=459, provider='Paul Nathan', frequency=6)
# Pandas(Index=460, provider='Trend Recognition', frequency=6)
# Pandas(Index=461, provider='Clive Maund', frequency=6)
# Pandas(Index=462, provider='Benedetto DiCostanzo', frequency=6)
# Pandas(Index=463, provider='Jason Rotman', frequency=6)
# Pandas(Index=464, provider='Bell Ringers/Investing.com', frequency=6)
# Pandas(Index=465, provider='Ajay Shah', frequency=6)
# Pandas(Index=466, provider='eToro', frequency=6)
# Pandas(Index=467, provider='Joshua Fruhlinger', frequency=6)
# Pandas(Index=468, provider='Nikolai Kuznetsov', frequency=6)
# Pandas(Index=469, provider='Elliott Gue', frequency=6)
# Pandas(Index=470, provider='Rupert Hargreaves', frequency=6)
# Pandas(Index=471, provider='Chris Capre', frequency=6)
# Pandas(Index=472, provider='Banc De Binary', frequency=6)
# Pandas(Index=473, provider='David Becker', frequency=6)
# Pandas(Index=474, provider='Spreadex', frequency=6)
# Pandas(Index=475, provider='Butler|Philbrick & Associates', frequency=6)
# Pandas(Index=476, provider='FX77', frequency=6)
# Pandas(Index=477, provider='Dmitry Karlov Jarsky', frequency=6)
# Pandas(Index=478, provider='Yuri Papshev', frequency=6)
# Pandas(Index=479, provider='Dutch Trader', frequency=6)
# Pandas(Index=480, provider='Blair Jensen', frequency=6)
# Pandas(Index=481, provider='Sarah Potter', frequency=6)
# Pandas(Index=482, provider='Katie Spence/Investing.com', frequency=6)
# Pandas(Index=483, provider='Alvexo', frequency=6)
# Pandas(Index=484, provider='Investingmoney.biz', frequency=5)
# Pandas(Index=485, provider='Satendra Singh', frequency=5)
# Pandas(Index=486, provider='Arnout Ter Schure', frequency=5)
# Pandas(Index=487, provider='Mark Green', frequency=5)
# Pandas(Index=488, provider='Robert Kientz', frequency=5)
# Pandas(Index=489, provider='MarketPulse', frequency=5)
# Pandas(Index=490, provider='Bob Kirtley', frequency=5)
# Pandas(Index=491, provider='Mukhriz Mangsor', frequency=5)
# Pandas(Index=492, provider='James Sarmiento', frequency=5)
# Pandas(Index=493, provider='ActivTrades', frequency=5)
# Pandas(Index=494, provider='Cumberland Advisors', frequency=5)
# Pandas(Index=495, provider='Sure Dividend', frequency=5)
# Pandas(Index=496, provider='Artur Oliveira', frequency=5)
# Pandas(Index=497, provider='Howard Goldstein', frequency=5)
# Pandas(Index=498, provider='Peter Schiff', frequency=5)
# Pandas(Index=499, provider='Carl Swenlin', frequency=5)
# Pandas(Index=500, provider='Omi Currency', frequency=5)
# Pandas(Index=501, provider='Aksel Kibar', frequency=5)
# Pandas(Index=502, provider='Andrey Sergeenkov', frequency=5)
# Pandas(Index=503, provider='Callum Thomas', frequency=5)
# Pandas(Index=504, provider='Admiral Markets', frequency=5)
# Pandas(Index=505, provider='EconMatters ', frequency=5)
# Pandas(Index=506, provider='David Levenstein', frequency=5)
# Pandas(Index=507, provider='Liston Street Pulse', frequency=5)
# Pandas(Index=508, provider='TradeRush', frequency=5)
# Pandas(Index=509, provider='Luis Aureliano', frequency=5)
# Pandas(Index=510, provider='Mike McAra', frequency=5)
# Pandas(Index=511, provider='Trader Steve', frequency=5)
# Pandas(Index=512, provider='Axel G. Merk', frequency=5)
# Pandas(Index=513, provider='John Mousseau', frequency=5)
# Pandas(Index=514, provider='Jeff Pierce', frequency=5)
# Pandas(Index=515, provider='Stephan Bogner', frequency=5)
# Pandas(Index=516, provider='Dara Albright', frequency=5)
# Pandas(Index=517, provider='Patrick Chovanec', frequency=5)
# Pandas(Index=518, provider='James Knightley', frequency=5)
# Pandas(Index=519, provider='BRUEGEL', frequency=5)
# Pandas(Index=520, provider='Plunger (Burt Coons)', frequency=5)
# Pandas(Index=521, provider='Adrian Filip', frequency=5)
# Pandas(Index=522, provider='Paul Daniel', frequency=4)
# Pandas(Index=523, provider='Andrew Sachais', frequency=4)
# Pandas(Index=524, provider='Jay Norris', frequency=4)
# Pandas(Index=525, provider='Tradesight', frequency=4)
# Pandas(Index=526, provider='Kate Curtis', frequency=4)
# Pandas(Index=527, provider='Ravee Mehta', frequency=4)
# Pandas(Index=528, provider='Todd Sohayda', frequency=4)
# Pandas(Index=529, provider='Nicky Ong', frequency=4)
# Pandas(Index=530, provider='Gene Andrews', frequency=4)
# Pandas(Index=531, provider='Tony Caldaro', frequency=4)
# Pandas(Index=532, provider='Fan Yang', frequency=4)
# Pandas(Index=533, provider='Richard Cox', frequency=4)
# Pandas(Index=534, provider='PFGBest Forex', frequency=4)
# Pandas(Index=535, provider='Christopher Lewis', frequency=4)
# Pandas(Index=536, provider='Craig Hemke', frequency=4)
# Pandas(Index=537, provider='James Gruber', frequency=4)
# Pandas(Index=538, provider='Erik McCurdy', frequency=4)
# Pandas(Index=539, provider='Keith Speights', frequency=4)
# Pandas(Index=540, provider='Elizaveta Belugina', frequency=4)
# Pandas(Index=541, provider='Narek Zakaryan', frequency=4)
# Pandas(Index=542, provider='Stavros Georgiadis', frequency=4)
# Pandas(Index=543, provider='Steven Goldstein', frequency=4)
# Pandas(Index=544, provider='Legal & General Investment Management', frequency=4)
# Pandas(Index=545, provider='Joe Marwood', frequency=4)
# Pandas(Index=546, provider='Juan Carlos Zuleta', frequency=4)
# Pandas(Index=547, provider='John Murphy', frequency=4)
# Pandas(Index=548, provider='Tom Davidson', frequency=4)
# Pandas(Index=549, provider='Evgeny Ilyukhin', frequency=4)
# Pandas(Index=550, provider='Jim Quinn', frequency=4)
# Pandas(Index=551, provider='BitMEX - Bitcoin Mercantile Exchange', frequency=4)
# Pandas(Index=552, provider='Professor Steve Keen', frequency=4)
# Pandas(Index=553, provider='InterTrader .com', frequency=4)
# Pandas(Index=554, provider='Iris Pang', frequency=4)
# Pandas(Index=555, provider='Wall Street Insanity', frequency=4)
# Pandas(Index=556, provider='Gregory Blotnick', frequency=4)
# Pandas(Index=557, provider='Christian Buhagiar', frequency=3)
# Pandas(Index=558, provider='news fxbase', frequency=3)
# Pandas(Index=559, provider='Sonya Colberg', frequency=3)
# Pandas(Index=560, provider='Gavin Pannu', frequency=3)
# Pandas(Index=561, provider='David Banister', frequency=3)
# Pandas(Index=562, provider='David Solin', frequency=3)
# Pandas(Index=563, provider='SGT Markets', frequency=3)
# Pandas(Index=564, provider='Nick Simpson', frequency=3)
# Pandas(Index=565, provider='The Dividend Daily', frequency=3)
# Pandas(Index=566, provider='Quantified Alpha', frequency=3)
# Pandas(Index=567, provider='Dawn richard', frequency=3)
# Pandas(Index=568, provider='All Things Forex', frequency=3)
# Pandas(Index=569, provider='JustForex', frequency=3)
# Pandas(Index=570, provider='BabyPips.com', frequency=3)
# Pandas(Index=571, provider='Benjamin Arie', frequency=3)
# Pandas(Index=572, provider='David Ben Melech', frequency=3)
# Pandas(Index=573, provider='Guy Manno', frequency=3)
# Pandas(Index=574, provider='Sankalp Soni', frequency=3)
# Pandas(Index=575, provider='Vinayak Maheswaran', frequency=3)
# Pandas(Index=576, provider='Epsilon', frequency=3)
# Pandas(Index=577, provider='Barry Norman', frequency=3)
# Pandas(Index=578, provider='Robert Sinn', frequency=3)
# Pandas(Index=579, provider='Darya Bobrova', frequency=3)
# Pandas(Index=580, provider='RulingTheMarkets', frequency=3)
# Pandas(Index=581, provider='Agnes Lovasz/Investing.com', frequency=3)
# Pandas(Index=582, provider='John Bell', frequency=3)
# Pandas(Index=583, provider='Nadia Simmons', frequency=3)
# Pandas(Index=584, provider='Michael Filighera', frequency=3)
# Pandas(Index=585, provider='Kira Iukhtenko', frequency=3)
# Pandas(Index=586, provider='KraneShares', frequency=3)
# Pandas(Index=587, provider='Austin Galt', frequency=3)
# Pandas(Index=588, provider='Trader 21 ', frequency=3)
# Pandas(Index=589, provider='Chris Marcus', frequency=3)
# Pandas(Index=590, provider='Macro Ops', frequency=3)
# Pandas(Index=591, provider='Dwaine van Vuuren', frequency=3)
# Pandas(Index=592, provider='Chris Lemieux', frequency=3)
# Pandas(Index=593, provider='John Mauldin', frequency=3)
# Pandas(Index=594, provider='David Redensky', frequency=3)
# Pandas(Index=595, provider='Forex Watchers', frequency=3)
# Pandas(Index=596, provider='Dr. Clifford Rossi', frequency=3)
# Pandas(Index=597, provider='Ivan Beljan', frequency=3)
# Pandas(Index=598, provider='Alpari', frequency=3)
# Pandas(Index=599, provider='MN Gordon', frequency=3)
# Pandas(Index=600, provider='MXTrade', frequency=3)
# Pandas(Index=601, provider='Patrick Watson', frequency=3)
# Pandas(Index=602, provider='The Individual Investor', frequency=3)
# Pandas(Index=603, provider='AG Thorson', frequency=3)
# Pandas(Index=604, provider='Blue Suisse', frequency=3)
# Pandas(Index=605, provider='Phil DeAngelo', frequency=3)
# Pandas(Index=606, provider='Takeover Analyst', frequency=3)
# Pandas(Index=607, provider='Chris Martenson', frequency=3)
# Pandas(Index=608, provider='Casey Stubbs', frequency=3)
# Pandas(Index=609, provider='Allrates', frequency=3)
# Pandas(Index=610, provider='Covesting Research', frequency=3)
# Pandas(Index=611, provider='Tradeview Forex', frequency=3)
# Pandas(Index=612, provider='Vuru Inc', frequency=3)
# Pandas(Index=613, provider='Roni Stern', frequency=3)
# Pandas(Index=614, provider='Scott Brown', frequency=3)
# Pandas(Index=615, provider='Keith Summers, CFA', frequency=3)
# Pandas(Index=616, provider='Emre Karaoglu', frequency=3)
# Pandas(Index=617, provider='Joshua Paul', frequency=3)
# Pandas(Index=618, provider='Bob Eisenbeis', frequency=3)
# Pandas(Index=619, provider='Elite Round Table', frequency=2)
# Pandas(Index=620, provider='TradePlacer', frequency=2)
# Pandas(Index=621, provider='Alasdair Macleod', frequency=2)
# Pandas(Index=622, provider='Elliot Chang', frequency=2)
# Pandas(Index=623, provider='Eric Pitou', frequency=2)
# Pandas(Index=624, provider='James Sackey', frequency=2)
# Pandas(Index=625, provider='IH Forex', frequency=2)
# Pandas(Index=626, provider='Rotem  Gvishi-Cohen', frequency=2)
# Pandas(Index=627, provider='Adam Collins', frequency=2)
# Pandas(Index=628, provider='Brian Fletcher', frequency=2)
# Pandas(Index=629, provider='Jake Peacock', frequency=2)
# Pandas(Index=630, provider='Kirk Du Plessis', frequency=2)
# Pandas(Index=631, provider='Dimitri Speck', frequency=2)
# Pandas(Index=632, provider='Michael Grogan', frequency=2)
# Pandas(Index=633, provider='Sam Laakso', frequency=2)
# Pandas(Index=634, provider='Kenneth Ashe', frequency=2)
# Pandas(Index=635, provider='Eli Schultz', frequency=2)
# Pandas(Index=636, provider='Tomasz Wisniewski', frequency=2)
# Pandas(Index=637, provider='Michael Dylan', frequency=2)
# Pandas(Index=638, provider='Estimize ', frequency=2)
# Pandas(Index=639, provider='Jason Hope', frequency=2)
# Pandas(Index=640, provider='Rob Hall', frequency=2)
# Pandas(Index=641, provider='Market Leader', frequency=2)
# Pandas(Index=642, provider='Profit Confidential', frequency=2)
# Pandas(Index=643, provider='Rida Morwa', frequency=2)
# Pandas(Index=644, provider='Furqan Saeed', frequency=2)
# Pandas(Index=645, provider='Greg Atkinson', frequency=2)
# Pandas(Index=646, provider='Dan Norcini', frequency=2)
# Pandas(Index=647, provider='Nishit Vadhavkar', frequency=2)
# Pandas(Index=648, provider='Kristen Moran', frequency=2)
# Pandas(Index=649, provider='Nicholas Rossolillo', frequency=2)
# Pandas(Index=650, provider='Kristján Gunnarsson', frequency=2)
# Pandas(Index=651, provider='BuzzInForex', frequency=2)
# Pandas(Index=652, provider='OctaFX', frequency=2)
# Pandas(Index=653, provider='David Cullinan', frequency=2)
# Pandas(Index=654, provider='Trading Advantage', frequency=2)
# Pandas(Index=655, provider='Dragonfly Capital', frequency=2)
# Pandas(Index=656, provider='Chris Berry', frequency=2)
# Pandas(Index=657, provider='Anjana Mittal', frequency=2)
# Pandas(Index=658, provider='F.F. Wiley', frequency=2)
# Pandas(Index=659, provider='Luis Fdez', frequency=2)
# Pandas(Index=660, provider='Danny Vena', frequency=2)
# Pandas(Index=661, provider='Steven P. Orlowski', frequency=2)
# Pandas(Index=662, provider='Adam White', frequency=2)
# Pandas(Index=663, provider='AutoChartist', frequency=2)
# Pandas(Index=664, provider='The Trader', frequency=2)
# Pandas(Index=665, provider='Principle Analysis', frequency=2)
# Pandas(Index=666, provider='Jesse Smythe', frequency=2)
# Pandas(Index=667, provider='Libertex', frequency=2)
# Pandas(Index=668, provider='FxGrow', frequency=2)
# Pandas(Index=669, provider='Value Digger', frequency=2)
# Pandas(Index=670, provider='Kenny Simon', frequency=2)
# Pandas(Index=671, provider='Dirk Friczewsky', frequency=2)
# Pandas(Index=672, provider='Bruce Pile', frequency=2)
# Pandas(Index=673, provider='Carlos X. Alexandre', frequency=2)
# Pandas(Index=674, provider='Fullerton Markets', frequency=2)
# Pandas(Index=675, provider='Carley Garner', frequency=2)
# Pandas(Index=676, provider='Chad Hagan', frequency=2)
# Pandas(Index=677, provider='Adam Levine-Weinberg', frequency=2)
# Pandas(Index=678, provider='Gordon Long', frequency=2)
# Pandas(Index=679, provider='Carsten Brzeski', frequency=2)
# Pandas(Index=680, provider='John Coumarianos', frequency=2)
# Pandas(Index=681, provider='Christopher Lourenco', frequency=2)
# Pandas(Index=682, provider='FxStocksData', frequency=2)
# Pandas(Index=683, provider='Brad Thomas', frequency=2)
# Pandas(Index=684, provider='Qatar National Bank', frequency=2)
# Pandas(Index=685, provider='Anatoly Grigoryev', frequency=2)
# Pandas(Index=686, provider='Konstantin Kaiser', frequency=2)
# Pandas(Index=687, provider='Peter Grant', frequency=2)
# Pandas(Index=688, provider='Alexander Borodich', frequency=2)
# Pandas(Index=689, provider='AmigoBulls', frequency=2)
# Pandas(Index=690, provider='mateusz zdyb', frequency=2)
# Pandas(Index=691, provider='Ed Liston', frequency=2)
# Pandas(Index=692, provider='Travis McPherson', frequency=2)
# Pandas(Index=693, provider='In The Money Stocks', frequency=2)
# Pandas(Index=694, provider='Michael Lebowitz', frequency=2)
# Pandas(Index=695, provider='My Trading Income', frequency=2)
# Pandas(Index=696, provider='Gary Dorsch', frequency=2)
# Pandas(Index=697, provider='James Brumley', frequency=2)
# Pandas(Index=698, provider='Julia Magas', frequency=2)
# Pandas(Index=699, provider='Vantage FX', frequency=2)
# Pandas(Index=700, provider='John B.', frequency=2)
# Pandas(Index=701, provider='Adam Taggart', frequency=2)
# Pandas(Index=702, provider='Shmulik Karpf', frequency=2)
# Pandas(Index=703, provider='Michael Fabian', frequency=2)
# Pandas(Index=704, provider='Piyush Arora', frequency=2)
# Pandas(Index=705, provider='Darrell Delamaide/Investing.com', frequency=2)
# Pandas(Index=706, provider='Juan Maldonado', frequency=2)
# Pandas(Index=707, provider='Amar Daryanani', frequency=2)
# Pandas(Index=708, provider='Chris Bailey', frequency=2)
# Pandas(Index=709, provider='John van der Munnik', frequency=2)
# Pandas(Index=710, provider='dmitry korolev', frequency=2)
# Pandas(Index=711, provider='Nicola Delic', frequency=2)
# Pandas(Index=712, provider='Stephen Loke', frequency=2)
# Pandas(Index=713, provider='Growth Aces', frequency=2)
# Pandas(Index=714, provider='Harley Salt', frequency=2)
# Pandas(Index=715, provider='George Dorgan', frequency=2)
# Pandas(Index=716, provider='Jesus Aldana', frequency=2)
# Pandas(Index=717, provider='Carl Cotton', frequency=2)
# Pandas(Index=718, provider='Peter C. Kenny', frequency=2)
# Pandas(Index=719, provider='Volatility Analytics Inc', frequency=2)
# Pandas(Index=720, provider='John Weyer', frequency=2)
# Pandas(Index=721, provider='Daryl Montgomery', frequency=2)
# Pandas(Index=722, provider='Steve Walker', frequency=2)
# Pandas(Index=723, provider='Leonardo Barata', frequency=2)
# Pandas(Index=724, provider='Chris Puplava', frequency=2)
# Pandas(Index=725, provider='Greg Group', frequency=2)
# Pandas(Index=726, provider='Peter Thomas', frequency=2)
# Pandas(Index=727, provider='Max Ganik', frequency=2)
# Pandas(Index=728, provider='Imperial Options', frequency=2)
# Pandas(Index=729, provider='Gary Savage', frequency=2)
# Pandas(Index=730, provider='Dan Murray', frequency=1)
# Pandas(Index=731, provider='Tarek Roustom', frequency=1)
# Pandas(Index=732, provider='Christopher Lemieux', frequency=1)
# Pandas(Index=733, provider='Shweta Bhasker shome', frequency=1)
# Pandas(Index=734, provider='ACFX', frequency=1)
# Pandas(Index=735, provider='Shaun Overton', frequency=1)
# Pandas(Index=736, provider='Jitan Solanki', frequency=1)
# Pandas(Index=737, provider='Scott Boyd', frequency=1)
# Pandas(Index=738, provider='I Know First Research ', frequency=1)
# Pandas(Index=739, provider='Daniel Fisher', frequency=1)
# Pandas(Index=740, provider='Dock David Treece', frequency=1)
# Pandas(Index=741, provider='Sid Klein', frequency=1)
# Pandas(Index=742, provider='David Fielder', frequency=1)
# Pandas(Index=743, provider='Thomas Schleusener', frequency=1)
# Pandas(Index=744, provider='Michael James', frequency=1)
# Pandas(Index=745, provider='Joe Sirianni', frequency=1)
# Pandas(Index=746, provider='Amit Gaurav CFA', frequency=1)
# Pandas(Index=747, provider='adam rossique', frequency=1)
# Pandas(Index=748, provider='Hitesh Haryani', frequency=1)
# Pandas(Index=749, provider='Andrew Masters', frequency=1)
# Pandas(Index=750, provider='Pepperstone', frequency=1)
# Pandas(Index=751, provider='divanshu sharma', frequency=1)
# Pandas(Index=752, provider='Navy Capital', frequency=1)
# Pandas(Index=753, provider='Sarah Peter', frequency=1)
# Pandas(Index=754, provider='Mark St. Cyr', frequency=1)
# Pandas(Index=755, provider='Jonathan Garza Cantú', frequency=1)
# Pandas(Index=756, provider='Surf City', frequency=1)
# Pandas(Index=757, provider='Gold Silver Worlds', frequency=1)
# Pandas(Index=758, provider='MahiFX', frequency=1)
# Pandas(Index=759, provider='Bram de Haas', frequency=1)
# Pandas(Index=760, provider='Graham Giller', frequency=1)
# Pandas(Index=761, provider='Frik Els', frequency=1)
# Pandas(Index=762, provider='Terry Grennon', frequency=1)
# Pandas(Index=763, provider='Prakash Sundaram', frequency=1)
# Pandas(Index=764, provider='Pharma lifeline', frequency=1)
# Pandas(Index=765, provider='James Turk', frequency=1)
# Pandas(Index=766, provider='Giuseppe Roccasalvo Joe Rok', frequency=1)
# Pandas(Index=767, provider='Julian Phillips', frequency=1)
# Pandas(Index=768, provider='CAGR VALUE', frequency=1)
# Pandas(Index=769, provider='Arthur Azizov', frequency=1)
# Pandas(Index=770, provider='Chrystala Parmaxi', frequency=1)
# Pandas(Index=771, provider='Adam Parris', frequency=1)
# Pandas(Index=772, provider='Inna Rosputnia', frequency=1)
# Pandas(Index=773, provider='Jamie Dutta', frequency=1)
# Pandas(Index=774, provider='Joel Wright', frequency=1)
# Pandas(Index=775, provider='Dave Rauschenfels', frequency=1)
# Pandas(Index=776, provider='Patrick Tan', frequency=1)
# Pandas(Index=777, provider='Chad Champion', frequency=1)
# Pandas(Index=778, provider='Suz Smith', frequency=1)
# Pandas(Index=779, provider='Airat Sattarov', frequency=1)
# Pandas(Index=780, provider='Action Forex', frequency=1)
# Pandas(Index=781, provider='Philip Baker', frequency=1)
# Pandas(Index=782, provider='Michael A. Gayed', frequency=1)
# Pandas(Index=783, provider='Sortis Invest', frequency=1)
# Pandas(Index=784, provider='Bart Brands', frequency=1)
# Pandas(Index=785, provider='Daniel Nevins', frequency=1)
# Pandas(Index=786, provider='Orion Trading LLC', frequency=1)
# Pandas(Index=787, provider='Omar Venerio', frequency=1)
# Pandas(Index=788, provider='Jacob Sander', frequency=1)
# Pandas(Index=789, provider='Anthony Randall', frequency=1)
# Pandas(Index=790, provider='Floyd Brown', frequency=1)
# Pandas(Index=791, provider='Daniel Sckolnik', frequency=1)
# Pandas(Index=792, provider='Ted Kavadas', frequency=1)
# Pandas(Index=793, provider='Charles Bovaird', frequency=1)
# Pandas(Index=794, provider='Ron Hera', frequency=1)
# Pandas(Index=795, provider='Matei Gavril', frequency=1)
# Pandas(Index=796, provider='Carl Lang', frequency=1)
# Pandas(Index=797, provider='Christoph Janß', frequency=1)
# Pandas(Index=798, provider='FX BAZOOKA', frequency=1)
# Pandas(Index=799, provider='Ravindra Dholakia', frequency=1)
# Pandas(Index=800, provider='Noreen Burke/Investing.com', frequency=1)
# Pandas(Index=801, provider='Gianluca Privitera', frequency=1)
# Pandas(Index=802, provider='Matt smith', frequency=1)
# Pandas(Index=803, provider='Nima Abbaszadeh', frequency=1)
# Pandas(Index=804, provider='Forex signals 24', frequency=1)
# Pandas(Index=805, provider='ValuEngine', frequency=1)
# Pandas(Index=806, provider='IFA Global', frequency=1)
# Pandas(Index=807, provider='OANDA', frequency=1)
# Pandas(Index=808, provider='Matt Smith', frequency=1)
# Pandas(Index=809, provider='Mark Hill', frequency=1)
# Pandas(Index=810, provider='Jack Smith', frequency=1)
# Pandas(Index=811, provider='Vinay Jha', frequency=1)
# Pandas(Index=812, provider='Michael Lewitt', frequency=1)
# Pandas(Index=813, provider='AllFXBrokers', frequency=1)
# Pandas(Index=814, provider='Ed Carlson', frequency=1)
# Pandas(Index=815, provider='Daily Capital Market Dose', frequency=1)
# Pandas(Index=816, provider='Colby Dugger', frequency=1)
# Pandas(Index=817, provider='George Maniere', frequency=1)
# Pandas(Index=818, provider='Dick Sterling', frequency=1)
# Pandas(Index=819, provider='RTT Admin', frequency=1)
# Pandas(Index=820, provider='Sam Kirtley', frequency=1)
# Pandas(Index=821, provider='Ruslan Zaripov', frequency=1)
# Pandas(Index=822, provider='Jameen Walker', frequency=1)
# Pandas(Index=823, provider='Sandy Miguel', frequency=1)
# Pandas(Index=824, provider='Brad Gilbert', frequency=1)
# Pandas(Index=825, provider='Gold Core', frequency=1)
# Pandas(Index=826, provider='Tom Cleveland', frequency=1)
# Pandas(Index=827, provider='G J Campbell', frequency=1)
# Pandas(Index=828, provider='Chad Gassaway', frequency=1)
# Pandas(Index=829, provider='Shrikant Sangani', frequency=1)
# Pandas(Index=830, provider='Rayman Partners', frequency=1)
# Pandas(Index=831, provider='Peter Epstein', frequency=1)
# Pandas(Index=832, provider='Steve Wain', frequency=1)
# Pandas(Index=833, provider='Avory & Co.', frequency=1)
# Pandas(Index=834, provider='David Kranzler', frequency=1)
# Pandas(Index=835, provider='Mark Sabol', frequency=1)
# Pandas(Index=836, provider='Abhishek M R', frequency=1)
# Pandas(Index=837, provider='Henrik Becker', frequency=1)
# Pandas(Index=838, provider='Teva Lama', frequency=1)
# Pandas(Index=839, provider='Benjamin Insurance', frequency=1)
# Pandas(Index=840, provider='John Lounsbury', frequency=1)
# Pandas(Index=841, provider='Capitalist Exploits', frequency=1)
# Pandas(Index=842, provider='Geoffrey Smith/Investing.com ', frequency=1)
# Pandas(Index=843, provider='Kirk Spano', frequency=1)
# Pandas(Index=844, provider='Keith Schneider', frequency=1)
# Pandas(Index=845, provider='Gene Lawson', frequency=1)
# Pandas(Index=846, provider='ForexCorporate', frequency=1)
# Pandas(Index=847, provider='James Cornehlsen', frequency=1)
# Pandas(Index=848, provider='Kim Klaiman', frequency=1)
# Pandas(Index=849, provider='Navin Kr', frequency=1)
# Pandas(Index=850, provider='Sean Lusk', frequency=1)
# Pandas(Index=851, provider='John Ducas', frequency=1)
# Pandas(Index=852, provider='Shai Koopman', frequency=1)
# Pandas(Index=853, provider='Thomas Hayes', frequency=1)
# Pandas(Index=854, provider='Kelvin Wong', frequency=1)
# Pandas(Index=855, provider='Simit Patel', frequency=1)
# Pandas(Index=856, provider='Rajesh Srivastava', frequency=1)
# Pandas(Index=857, provider='Tandem Capital', frequency=1)
# Pandas(Index=858, provider='Jameel Ahmad', frequency=1)
# Pandas(Index=859, provider='Keith Mann', frequency=1)
# Pandas(Index=860, provider='Chris Kline', frequency=1)
# Pandas(Index=861, provider='Raju Angadi Vishwanath', frequency=1)
# Pandas(Index=862, provider='Oleg Spilka', frequency=1)
# Pandas(Index=863, provider='Winston Nguyen', frequency=1)
# Pandas(Index=864, provider='Chris Porteous', frequency=1)
# Pandas(Index=865, provider='All About Trends', frequency=1)
# Pandas(Index=866, provider='Tim Kathlina', frequency=1)
# Pandas(Index=867, provider='Carol Harmer', frequency=1)
# Pandas(Index=868, provider='Alex Gurr', frequency=1)
# Pandas(Index=869, provider='Razvan Podariu', frequency=1)
# Pandas(Index=870, provider='Justin Simon', frequency=1)
# Pandas(Index=871, provider='Jan Hortebusch', frequency=1)
# Pandas(Index=872, provider='Bryan Bourgeois', frequency=1)
# Pandas(Index=873, provider='Alexander Green', frequency=1)
# Pandas(Index=874, provider='Vishesh Raisinghani', frequency=1)
# Pandas(Index=875, provider='Puneet Sikka', frequency=1)
# Pandas(Index=876, provider='CMTrading', frequency=1)
# Pandas(Index=877, provider='Robert Irr', frequency=1)
# Pandas(Index=878, provider='Kiril Lebedev', frequency=1)
# Pandas(Index=879, provider='Daniel Sesay', frequency=1)
# Pandas(Index=880, provider='Blog of HORAN Capital Advisors ', frequency=1)
# Pandas(Index=881, provider='Santa Zvaigzne', frequency=1)
# Pandas(Index=882, provider='Ridge Capital Markets', frequency=1)
# Pandas(Index=883, provider='Elliott Wave Forecast ', frequency=1)
# Pandas(Index=884, provider='Patrick Foot', frequency=1)
# Pandas(Index=885, provider='Jay Goldman', frequency=1)
# Pandas(Index=886, provider='Forex Metal', frequency=1)
# Pandas(Index=887, provider='Anthony Welch', frequency=1)
# Pandas(Index=888, provider='Rob Marstrand', frequency=1)
# Pandas(Index=889, provider='Russ Fischer', frequency=1)
# Pandas(Index=890, provider='Maria Pittashi', frequency=1)
# Pandas(Index=891, provider='George Dagher', frequency=1)
# Pandas(Index=892, provider='ReThink Market Advisors', frequency=1)
# Pandas(Index=893, provider='Sarfaraz A Khan', frequency=1)
# Pandas(Index=894, provider='RoboForex', frequency=1)
# Pandas(Index=895, provider='Jason Sen', frequency=1)
# Pandas(Index=896, provider='Kenneth Feigeles', frequency=1)
# Pandas(Index=897, provider='Economics Global', frequency=1)
# Pandas(Index=898, provider='Adam Hewison', frequency=1)
# Pandas(Index=899, provider='Iliya Zaki Bin Aziz', frequency=1)
# Pandas(Index=900, provider='Trading WithWaves', frequency=1)
# Pandas(Index=901, provider='Marketprog', frequency=1)
# Pandas(Index=902, provider='Billionairies Portfolio billionairesportfolio.com', frequency=1)
# Pandas(Index=903, provider='Lance Jepsen', frequency=1)
# Pandas(Index=904, provider='Dr Priyanka Sharma', frequency=1)
# Pandas(Index=905, provider='Clive Hale', frequency=1)
# Pandas(Index=906, provider='Daily Marijuana Observer', frequency=1)
# Pandas(Index=907, provider='Gregory Weldon', frequency=1)
# Pandas(Index=908, provider='Sprott Money Ltd.', frequency=1)
# Pandas(Index=909, provider='Jose Merino', frequency=1)
# Pandas(Index=910, provider='Trade12.', frequency=1)
# Pandas(Index=911, provider='Anurag Gautam', frequency=1)
# Pandas(Index=912, provider='Scott Silva', frequency=1)
# Pandas(Index=913, provider='Korbinian Koller', frequency=1)
# Pandas(Index=914, provider='John Persinos', frequency=1)
# Pandas(Index=915, provider='Tim Hannagan', frequency=1)
# Pandas(Index=916, provider='John IFC', frequency=1)
# Pandas(Index=917, provider='Jackson Che', frequency=1)
# Pandas(Index=918, provider='Reid Kirchenbauer', frequency=1)
# Pandas(Index=919, provider='Thomas White', frequency=1)
# Pandas(Index=920, provider='ESI Analytics Limited', frequency=1)
# Pandas(Index=921, provider='Douglas Busch', frequency=1)
# Pandas(Index=922, provider='The Token Fund', frequency=1)
# Pandas(Index=923, provider='Przemyslaw Radomski, CFA', frequency=1)
# Pandas(Index=924, provider='Ari Glass', frequency=1)
# Pandas(Index=925, provider='Adam Teen', frequency=1)
# Pandas(Index=926, provider='Liquid Markets', frequency=1)
# Pandas(Index=927, provider='Robert Martin Williams', frequency=1)
# Pandas(Index=928, provider='Dominic Cimino', frequency=1)
# Pandas(Index=929, provider="Akram's Razor", frequency=1)
# Pandas(Index=930, provider='Bill Achola', frequency=1)
# Pandas(Index=931, provider='Geoffrey Smith/Investing.com', frequency=1)
# Pandas(Index=932, provider='Corey Mergenthaler', frequency=1)
# Pandas(Index=933, provider='Forex Million', frequency=1)
# Pandas(Index=934, provider='Riken Mehta', frequency=1)
# Pandas(Index=935, provider='Steve Blade', frequency=1)
# Pandas(Index=936, provider='Taylor Carver', frequency=1)
# Pandas(Index=937, provider='Mike Macdonald', frequency=1)
# Pandas(Index=938, provider='James Dondero', frequency=1)
# Pandas(Index=939, provider='James Berkley', frequency=1)
# Pandas(Index=940, provider='Jesse Frehling', frequency=1)
# Pandas(Index=941, provider='Land of Trading', frequency=1)
# Pandas(Index=942, provider='Madhukar Bhatia', frequency=1)
# Pandas(Index=943, provider='TipRanks Ltd', frequency=1)
# Pandas(Index=944, provider='Bill Gunderson', frequency=1)
# Pandas(Index=945, provider='Sofien Kaabar', frequency=1)
# Pandas(Index=946, provider='Brian Twomey', frequency=1)
# Pandas(Index=947, provider='Priyesh Mehta', frequency=1)
# Pandas(Index=948, provider='Trevellyan Ward', frequency=1)
# Pandas(Index=949, provider='Ross Woodfield', frequency=1)
# Pandas(Index=950, provider='Bobby Braulio', frequency=1)
# Pandas(Index=951, provider='LA Little', frequency=1)
# Pandas(Index=952, provider='David Pinsen', frequency=1)
# Pandas(Index=953, provider='MainsStreetTrading ', frequency=1)
# Pandas(Index=954, provider='Nat Stewart', frequency=1)
# Pandas(Index=955, provider='Jason Haver', frequency=1)
# Pandas(Index=956, provider='Kevin Donovan', frequency=1)
# Pandas(Index=957, provider='David Fric', frequency=1)
# Pandas(Index=958, provider='Smarter Analyst', frequency=1)
# Pandas(Index=959, provider="Bob O'Donnell", frequency=1)
# Pandas(Index=960, provider='Emma Cox', frequency=1)
# Pandas(Index=961, provider='Pacific Park Financial Inc.', frequency=1)
# Pandas(Index=962, provider='Ivica Atanasovski', frequency=1)
# Pandas(Index=963, provider='Brent Carrier', frequency=1)
# Pandas(Index=964, provider='Justin S. Bennett', frequency=1)
# Pandas(Index=965, provider='Kison Patel', frequency=1)
# Pandas(Index=966, provider='Arthur Chachuna', frequency=1)
# Pandas(Index=967, provider='Martin Goersch', frequency=1)
# Pandas(Index=968, provider='Curt Dalton', frequency=1)
# Pandas(Index=969, provider='Contrarian Outlook', frequency=1)
# Pandas(Index=970, provider='Tae Jin Kang', frequency=1)
# Pandas(Index=971, provider='Kobus Kemp', frequency=1)
# Pandas(Index=972, provider='Tim Taylor', frequency=1)
# Pandas(Index=973, provider='Edison ', frequency=1)
# Pandas(Index=974, provider='Trade2Live', frequency=1)
# Pandas(Index=975, provider='Jim Taylor', frequency=1)
# Pandas(Index=976, provider='Dividend Investments', frequency=1)
# Pandas(Index=977, provider='Bob Ciura', frequency=1)
# Pandas(Index=978, provider='Dudley Pierce Baker', frequency=1)

# %%
# filter the dataset, only analyze those that have published more than 1000 times
provider_count_filter = provider_count[provider_count["frequency"] >= 1000]

# %%
provider_count_filter
# Out:
#                     provider  frequency
# 0  Zacks Investment Research      88071
# 1                    Reuters      55095
# 2              Investing.com      18466
# 3              Seeking Alpha      12987
# 4                  Bloomberg       3422
# 5            The Motley Fool       1251
# 6          Nicholas Santiago       1065

# %%
plt.figure(figsize=(50,50))


plt.xlabel('provider')
plt.ylabel('frequency')

ax = sns.barplot(x="provider", y="frequency" , palette="pastel", edgecolor=".6", data=provider_count_filter)
ax.bar_label(ax.containers[0])


sns.despine()

# %% [markdown]
# # Cantidad de noticias por año

# %%
# Copy and create a new dataset
new_df = df.copy()

# %%
# Creo una nueva columna en la que solo pongo el anio de la noticia, para ello
# convierto la columna "release_date" en tipo datetime para acceder a la propiedad year 
new_df['release_date_year'] = pd.to_datetime(new_df['release_date']).dt.year

# %%
new_df
# Out:
#             id ticker                                              title  \
# 0       221515    NIO  Why Shares of Chinese Electric Car Maker NIO A...
# 1       221516    NIO  NIO only consumer gainer  Workhorse Group amon...
# 2       221517    NIO  NIO leads consumer gainers  Beyond Meat and Ma...
# 3       221518    NIO                  NIO  NVAX among premarket gainers
# 4       221519    NIO                  PLUG  NIO among premarket gainers
# ...        ...    ...                                                ...
# 221508  443024      T                     Crude And Steel Still In Sync
# 221509  443025      T  Forget AT T  This Is The Telecom Stock You Sho...
# 221510  443026      T  Wall Street Exposed   Part 3   How Dividends C...
# 221511  443027      T       Weighing The Week Ahead  It s All About Jobs
# 221512  443028      T  Leap Wireless  LEAP    JPM Note and AT T   T M...
#
#        category                                            content  \
# 0          news  What s happening\nShares of Chinese electric c...
# 1          news  Gainers  NIO  NYSE NIO   7  \nLosers  MGP Ingr...
# 2          news  Gainers  NIO  NYSE NIO   14   Village Farms In...
# 3          news  Cemtrex  NASDAQ CETX   85  after FY results \n...
# 4          news  aTyr Pharma  NASDAQ LIFE   63  on Kyorin Pharm...
# ...         ...                                                ...
# 221508  opinion  We have been reporting on the trade off betwee...
# 221509  opinion  It s the largest cell phone provider in the wo...
# 221510  opinion  Before we dicuss how the mechanism of dividend...
# 221511  opinion  From start to finish  the coming week will hav...
# 221512  opinion  Leap Wireless International  Inc   Leap  is a ...
#
#        release_date         provider  \
# 0        2020-01-15  The Motley Fool
# 1        2020-01-18    Seeking Alpha
# 2        2020-01-15    Seeking Alpha
# 3        2020-01-15    Seeking Alpha
# 4        2020-01-06    Seeking Alpha
# ...             ...              ...
# 221508   2012-10-04       Ivan Kitov
# 221509   2012-05-30  StreetAuthority
# 221510   2012-07-16   Portfolio Cafe
# 221511   2012-09-02      Jeff Miller
# 221512   2011-12-31   Ophir Gottlieb
#
#                                                       url  article_id  \
# 0                                  https://invst.ly/pigqi     2060327
# 1                                  https://invst.ly/pje9c     2062196
# 2                                  https://invst.ly/pifmv     2060249
# 3                                  https://invst.ly/picu8     2060039
# 4       https://seekingalpha.com/news/3529772-plug-nio...     2053096
# ...                                                   ...         ...
# 221508  https://www.investing.com/analysis/crude-and-s...      138733
# 221509  https://www.investing.com/analysis/forget-at-t...      124829
# 221510  https://www.investing.com/analysis/wall-street...      129651
# 221511  https://www.investing.com/analysis/weighing-th...      134926
# 221512  https://www.investing.com/analysis/leap-wirele...      110079
#
#         release_date_year
# 0                    2020
# 1                    2020
# 2                    2020
# 3                    2020
# 4                    2020
# ...                   ...
# 221508               2012
# 221509               2012
# 221510               2012
# 221511               2012
# 221512               2011
#
# [221505 rows x 10 columns]

# %%
news_per_year_count = new_df["release_date_year"].value_counts()\
    .reset_index()\
    .rename(columns={'index': 'year', 'release_date_year': 'news_per_year'})


for i, row in enumerate(news_per_year_count.itertuples(), 0):
    print(row)
# Out:
# Pandas(Index=0, year=2019, news_per_year=58003)
# Pandas(Index=1, year=2018, news_per_year=42605)
# Pandas(Index=2, year=2017, news_per_year=41634)
# Pandas(Index=3, year=2016, news_per_year=28551)
# Pandas(Index=4, year=2015, news_per_year=12661)
# Pandas(Index=5, year=2020, news_per_year=9346)
# Pandas(Index=6, year=2013, news_per_year=8312)
# Pandas(Index=7, year=2012, news_per_year=7009)
# Pandas(Index=8, year=2014, news_per_year=5958)
# Pandas(Index=9, year=2009, news_per_year=4514)
# Pandas(Index=10, year=2011, news_per_year=2215)
# Pandas(Index=11, year=2008, news_per_year=479)
# Pandas(Index=12, year=2010, news_per_year=218)

# %%
# The number of publications per year is plotted
plt.figure(figsize=(50,50))

plt.xlabel('provider')
plt.ylabel('frequency')

ax = sns.barplot(x="year", y="news_per_year" , palette="pastel", edgecolor=".6", data=news_per_year_count)
ax.bar_label(ax.containers[0])
sns.despine()

# %% [markdown]
# # Cantidad de noticias por ticker

# %%
news_per_ticker_count = new_df["ticker"].value_counts()\
    .reset_index()\
    .rename(columns={'index': 'ticker', 'ticker': 'news_per_ticker'})


for i, row in enumerate(news_per_ticker_count.itertuples(), 0):
    print(row)
# Out:
# Pandas(Index=0, ticker='AAPL', news_per_ticker=20231)
# Pandas(Index=1, ticker='MSFT', news_per_ticker=8110)
# Pandas(Index=2, ticker='BAC', news_per_ticker=7408)
# Pandas(Index=3, ticker='AMZN', news_per_ticker=6330)
# Pandas(Index=4, ticker='NWSA', news_per_ticker=5914)
# Pandas(Index=5, ticker='BA', news_per_ticker=5879)
# Pandas(Index=6, ticker='GOOGL', news_per_ticker=5171)
# Pandas(Index=7, ticker='GS', news_per_ticker=4513)
# Pandas(Index=8, ticker='TSLA', news_per_ticker=4283)
# Pandas(Index=9, ticker='NFLX', news_per_ticker=3806)
# Pandas(Index=10, ticker='TGT', news_per_ticker=3689)
# Pandas(Index=11, ticker='INTC', news_per_ticker=3188)
# Pandas(Index=12, ticker='DIS', news_per_ticker=2875)
# Pandas(Index=13, ticker='XOM', news_per_ticker=2831)
# Pandas(Index=14, ticker='JPM', news_per_ticker=2600)
# Pandas(Index=15, ticker='MS', news_per_ticker=2498)
# Pandas(Index=16, ticker='GM', news_per_ticker=2089)
# Pandas(Index=17, ticker='C', news_per_ticker=2081)
# Pandas(Index=18, ticker='GE', news_per_ticker=2045)
# Pandas(Index=19, ticker='MU', news_per_ticker=1927)
# Pandas(Index=20, ticker='TM', news_per_ticker=1820)
# Pandas(Index=21, ticker='WMB', news_per_ticker=1482)
# Pandas(Index=22, ticker='KO', news_per_ticker=1367)
# Pandas(Index=23, ticker='WFC', news_per_ticker=1359)
# Pandas(Index=24, ticker='WMT', news_per_ticker=1267)
# Pandas(Index=25, ticker='IBM', news_per_ticker=1249)
# Pandas(Index=26, ticker='UBER', news_per_ticker=1222)
# Pandas(Index=27, ticker='BLK', news_per_ticker=1186)
# Pandas(Index=28, ticker='CME', news_per_ticker=1153)
# Pandas(Index=29, ticker='CVX', news_per_ticker=1105)
# Pandas(Index=30, ticker='AA', news_per_ticker=1079)
# Pandas(Index=31, ticker='CMG', news_per_ticker=1033)
# Pandas(Index=32, ticker='SO', news_per_ticker=979)
# Pandas(Index=33, ticker='VZ', news_per_ticker=941)
# Pandas(Index=34, ticker='LMT', news_per_ticker=937)
# Pandas(Index=35, ticker='EFX', news_per_ticker=873)
# Pandas(Index=36, ticker='CAT', news_per_ticker=872)
# Pandas(Index=37, ticker='BKR', news_per_ticker=854)
# Pandas(Index=38, ticker='SBUX', news_per_ticker=845)
# Pandas(Index=39, ticker='AGN', news_per_ticker=823)
# Pandas(Index=40, ticker='SLB', news_per_ticker=788)
# Pandas(Index=41, ticker='JNJ', news_per_ticker=763)
# Pandas(Index=42, ticker='T', news_per_ticker=759)
# Pandas(Index=43, ticker='NKE', news_per_ticker=753)
# Pandas(Index=44, ticker='PGR', news_per_ticker=697)
# Pandas(Index=45, ticker='AMGN', news_per_ticker=688)
# Pandas(Index=46, ticker='ICE', news_per_ticker=630)
# Pandas(Index=47, ticker='FCX', news_per_ticker=618)
# Pandas(Index=48, ticker='HD', news_per_ticker=614)
# Pandas(Index=49, ticker='FDX', news_per_ticker=609)
# Pandas(Index=50, ticker='ENGIE', news_per_ticker=597)
# Pandas(Index=51, ticker='DAL', news_per_ticker=597)
# Pandas(Index=52, ticker='UBSG', news_per_ticker=592)
# Pandas(Index=53, ticker='PG', news_per_ticker=584)
# Pandas(Index=54, ticker='SNE', news_per_ticker=584)
# Pandas(Index=55, ticker='MRK', news_per_ticker=575)
# Pandas(Index=56, ticker='CAJ', news_per_ticker=546)
# Pandas(Index=57, ticker='PFE', news_per_ticker=545)
# Pandas(Index=58, ticker='ADP', news_per_ticker=543)
# Pandas(Index=59, ticker='JWN', news_per_ticker=540)
# Pandas(Index=60, ticker='BHC', news_per_ticker=526)
# Pandas(Index=61, ticker='AVGO', news_per_ticker=517)
# Pandas(Index=62, ticker='NLOK', news_per_ticker=513)
# Pandas(Index=63, ticker='HUM', news_per_ticker=500)
# Pandas(Index=64, ticker='FMC', news_per_ticker=497)
# Pandas(Index=65, ticker='COST', news_per_ticker=492)
# Pandas(Index=66, ticker='BX', news_per_ticker=489)
# Pandas(Index=67, ticker='MCD', news_per_ticker=475)
# Pandas(Index=68, ticker='LLY', news_per_ticker=469)
# Pandas(Index=69, ticker='UAL', news_per_ticker=461)
# Pandas(Index=70, ticker='STZ', news_per_ticker=460)
# Pandas(Index=71, ticker='COP', news_per_ticker=459)
# Pandas(Index=72, ticker='BBY', news_per_ticker=457)
# Pandas(Index=73, ticker='CMCSA', news_per_ticker=451)
# Pandas(Index=74, ticker='NOC', news_per_ticker=441)
# Pandas(Index=75, ticker='DUK', news_per_ticker=440)
# Pandas(Index=76, ticker='AXP', news_per_ticker=436)
# Pandas(Index=77, ticker='HMC', news_per_ticker=428)
# Pandas(Index=78, ticker='BIIB', news_per_ticker=425)
# Pandas(Index=79, ticker='MMM', news_per_ticker=421)
# Pandas(Index=80, ticker='DXPE', news_per_ticker=421)
# Pandas(Index=81, ticker='ASML', news_per_ticker=417)
# Pandas(Index=82, ticker='NVDA', news_per_ticker=415)
# Pandas(Index=83, ticker='MYL', news_per_ticker=412)
# Pandas(Index=84, ticker='DD', news_per_ticker=408)
# Pandas(Index=85, ticker='GILD', news_per_ticker=404)
# Pandas(Index=86, ticker='ORCL', news_per_ticker=403)
# Pandas(Index=87, ticker='ADBE', news_per_ticker=403)
# Pandas(Index=88, ticker='BIDU', news_per_ticker=402)
# Pandas(Index=89, ticker='VALE', news_per_ticker=395)
# Pandas(Index=90, ticker='CSCO', news_per_ticker=390)
# Pandas(Index=91, ticker='SPGI', news_per_ticker=389)
# Pandas(Index=92, ticker='KBH', news_per_ticker=387)
# Pandas(Index=93, ticker='AZO', news_per_ticker=382)
# Pandas(Index=94, ticker='MA', news_per_ticker=378)
# Pandas(Index=95, ticker='ANF', news_per_ticker=374)
# Pandas(Index=96, ticker='PM', news_per_ticker=372)
# Pandas(Index=97, ticker='URBN', news_per_ticker=369)
# Pandas(Index=98, ticker='PBR', news_per_ticker=366)
# Pandas(Index=99, ticker='HSY', news_per_ticker=362)
# Pandas(Index=100, ticker='BMY', news_per_ticker=362)
# Pandas(Index=101, ticker='NEM', news_per_ticker=358)
# Pandas(Index=102, ticker='NYT', news_per_ticker=356)
# Pandas(Index=103, ticker='DE', news_per_ticker=355)
# Pandas(Index=104, ticker='QCOM', news_per_ticker=355)
# Pandas(Index=105, ticker='CBRE', news_per_ticker=353)
# Pandas(Index=106, ticker='NDAQ', news_per_ticker=352)
# Pandas(Index=107, ticker='ISRG', news_per_ticker=343)
# Pandas(Index=108, ticker='CPB', news_per_ticker=334)
# Pandas(Index=109, ticker='HAS', news_per_ticker=333)
# Pandas(Index=110, ticker='FTI', news_per_ticker=332)
# Pandas(Index=111, ticker='TIF', news_per_ticker=329)
# Pandas(Index=112, ticker='PXD', news_per_ticker=328)
# Pandas(Index=113, ticker='UNH', news_per_ticker=327)
# Pandas(Index=114, ticker='JBLU', news_per_ticker=324)
# Pandas(Index=115, ticker='WYNN', news_per_ticker=324)
# Pandas(Index=116, ticker='BKNG', news_per_ticker=324)
# Pandas(Index=117, ticker='VRTX', news_per_ticker=320)
# Pandas(Index=118, ticker='STT', news_per_ticker=317)
# Pandas(Index=119, ticker='TTM', news_per_ticker=317)
# Pandas(Index=120, ticker='VAR', news_per_ticker=316)
# Pandas(Index=121, ticker='UNP', news_per_ticker=313)
# Pandas(Index=122, ticker='MSI', news_per_ticker=313)
# Pandas(Index=123, ticker='GRMN', news_per_ticker=310)
# Pandas(Index=124, ticker='RL', news_per_ticker=308)
# Pandas(Index=125, ticker='NTRS', news_per_ticker=308)
# Pandas(Index=126, ticker='EXPE', news_per_ticker=306)
# Pandas(Index=127, ticker='MAR', news_per_ticker=300)
# Pandas(Index=128, ticker='PNC', news_per_ticker=299)
# Pandas(Index=129, ticker='DNKN', news_per_ticker=299)
# Pandas(Index=130, ticker='YUM', news_per_ticker=299)
# Pandas(Index=131, ticker='VLO', news_per_ticker=294)
# Pandas(Index=132, ticker='POLYP', news_per_ticker=292)
# Pandas(Index=133, ticker='LEN', news_per_ticker=291)
# Pandas(Index=134, ticker='MKC', news_per_ticker=290)
# Pandas(Index=135, ticker='ANIK', news_per_ticker=290)
# Pandas(Index=136, ticker='AIG', news_per_ticker=288)
# Pandas(Index=137, ticker='ETN', news_per_ticker=287)
# Pandas(Index=138, ticker='AMED', news_per_ticker=284)
# Pandas(Index=139, ticker='DRI', news_per_ticker=283)
# Pandas(Index=140, ticker='APA', news_per_ticker=283)
# Pandas(Index=141, ticker='ACN', news_per_ticker=282)
# Pandas(Index=142, ticker='FSLR', news_per_ticker=280)
# Pandas(Index=143, ticker='NEE', news_per_ticker=280)
# Pandas(Index=144, ticker='ALGT', news_per_ticker=280)
# Pandas(Index=145, ticker='J', news_per_ticker=276)
# Pandas(Index=146, ticker='CHTR', news_per_ticker=276)
# Pandas(Index=147, ticker='WHR', news_per_ticker=275)
# Pandas(Index=148, ticker='KSS', news_per_ticker=274)
# Pandas(Index=149, ticker='EL', news_per_ticker=274)
# Pandas(Index=150, ticker='TSN', news_per_ticker=272)
# Pandas(Index=151, ticker='M', news_per_ticker=270)
# Pandas(Index=152, ticker='TEVA', news_per_ticker=270)
# Pandas(Index=153, ticker='APD', news_per_ticker=269)
# Pandas(Index=154, ticker='GIS', news_per_ticker=267)
# Pandas(Index=155, ticker='HON', news_per_ticker=264)
# Pandas(Index=156, ticker='CI', news_per_ticker=261)
# Pandas(Index=157, ticker='PEP', news_per_ticker=261)
# Pandas(Index=158, ticker='CMI', news_per_ticker=257)
# Pandas(Index=159, ticker='THC', news_per_ticker=255)
# Pandas(Index=160, ticker='A', news_per_ticker=254)
# Pandas(Index=161, ticker='RGLD', news_per_ticker=254)
# Pandas(Index=162, ticker='PRU', news_per_ticker=251)
# Pandas(Index=163, ticker='UTX', news_per_ticker=250)
# Pandas(Index=164, ticker='CSIQ', news_per_ticker=248)
# Pandas(Index=165, ticker='DELL', news_per_ticker=247)
# Pandas(Index=166, ticker='ROST', news_per_ticker=245)
# Pandas(Index=167, ticker='ABT', news_per_ticker=240)
# Pandas(Index=168, ticker='MDT', news_per_ticker=240)
# Pandas(Index=169, ticker='AEM', news_per_ticker=236)
# Pandas(Index=170, ticker='WBA', news_per_ticker=235)
# Pandas(Index=171, ticker='BBBY', news_per_ticker=233)
# Pandas(Index=172, ticker='INTU', news_per_ticker=231)
# Pandas(Index=173, ticker='WDC', news_per_ticker=229)
# Pandas(Index=174, ticker='PPG', news_per_ticker=229)
# Pandas(Index=175, ticker='ALXN', news_per_ticker=228)
# Pandas(Index=176, ticker='CB', news_per_ticker=228)
# Pandas(Index=177, ticker='BIG', news_per_ticker=227)
# Pandas(Index=178, ticker='STLD', news_per_ticker=226)
# Pandas(Index=179, ticker='ETFC', news_per_ticker=226)
# Pandas(Index=180, ticker='SHW', news_per_ticker=224)
# Pandas(Index=181, ticker='CHN', news_per_ticker=224)
# Pandas(Index=182, ticker='DDS', news_per_ticker=224)
# Pandas(Index=183, ticker='INFY', news_per_ticker=223)
# Pandas(Index=184, ticker='ALGN', news_per_ticker=220)
# Pandas(Index=185, ticker='BXP', news_per_ticker=220)
# Pandas(Index=186, ticker='MTB', news_per_ticker=219)
# Pandas(Index=187, ticker='COLM', news_per_ticker=219)
# Pandas(Index=188, ticker='XRX', news_per_ticker=218)
# Pandas(Index=189, ticker='EQIX', news_per_ticker=218)
# Pandas(Index=190, ticker='FII', news_per_ticker=217)
# Pandas(Index=191, ticker='ABC', news_per_ticker=216)
# Pandas(Index=192, ticker='CTAS', news_per_ticker=216)
# Pandas(Index=193, ticker='AMD', news_per_ticker=216)
# Pandas(Index=194, ticker='UPS', news_per_ticker=212)
# Pandas(Index=195, ticker='BAX', news_per_ticker=211)
# Pandas(Index=196, ticker='RTN', news_per_ticker=211)
# Pandas(Index=197, ticker='CINF', news_per_ticker=211)
# Pandas(Index=198, ticker='NUE', news_per_ticker=210)
# Pandas(Index=199, ticker='DVN', news_per_ticker=209)
# Pandas(Index=200, ticker='EA', news_per_ticker=209)
# Pandas(Index=201, ticker='GPS', news_per_ticker=209)
# Pandas(Index=202, ticker='TTWO', news_per_ticker=208)
# Pandas(Index=203, ticker='EBAY', news_per_ticker=208)
# Pandas(Index=204, ticker='CRM', news_per_ticker=207)
# Pandas(Index=205, ticker='SCHW', news_per_ticker=206)
# Pandas(Index=206, ticker='DLTR', news_per_ticker=203)
# Pandas(Index=207, ticker='ROP', news_per_ticker=202)
# Pandas(Index=208, ticker='AMAT', news_per_ticker=202)
# Pandas(Index=209, ticker='CTL', news_per_ticker=202)
# Pandas(Index=210, ticker='WYND', news_per_ticker=201)
# Pandas(Index=211, ticker='DISH', news_per_ticker=201)
# Pandas(Index=212, ticker='CF', news_per_ticker=199)
# Pandas(Index=213, ticker='LRCX', news_per_ticker=198)
# Pandas(Index=214, ticker='LBTYA', news_per_ticker=196)
# Pandas(Index=215, ticker='EW', news_per_ticker=195)
# Pandas(Index=216, ticker='MO', news_per_ticker=195)
# Pandas(Index=217, ticker='EOG', news_per_ticker=194)
# Pandas(Index=218, ticker='V', news_per_ticker=193)
# Pandas(Index=219, ticker='UAA', news_per_ticker=192)
# Pandas(Index=220, ticker='XEL', news_per_ticker=191)
# Pandas(Index=221, ticker='BJRI', news_per_ticker=190)
# Pandas(Index=222, ticker='COF', news_per_ticker=190)
# Pandas(Index=223, ticker='AVY', news_per_ticker=189)
# Pandas(Index=224, ticker='EXPD', news_per_ticker=187)
# Pandas(Index=225, ticker='CMTL', news_per_ticker=186)
# Pandas(Index=226, ticker='DTE', news_per_ticker=185)
# Pandas(Index=227, ticker='K', news_per_ticker=185)
# Pandas(Index=228, ticker='AVB', news_per_ticker=185)
# Pandas(Index=229, ticker='GL', news_per_ticker=185)
# Pandas(Index=230, ticker='CMA', news_per_ticker=184)
# Pandas(Index=231, ticker='GD', news_per_ticker=183)
# Pandas(Index=232, ticker='AIZ', news_per_ticker=183)
# Pandas(Index=233, ticker='KR', news_per_ticker=181)
# Pandas(Index=234, ticker='KHC', news_per_ticker=181)
# Pandas(Index=235, ticker='YNDX', news_per_ticker=181)
# Pandas(Index=236, ticker='SYY', news_per_ticker=181)
# Pandas(Index=237, ticker='KMX', news_per_ticker=180)
# Pandas(Index=238, ticker='WFTLF', news_per_ticker=180)
# Pandas(Index=239, ticker='SJM', news_per_ticker=180)
# Pandas(Index=240, ticker='XLNX', news_per_ticker=179)
# Pandas(Index=241, ticker='MCO', news_per_ticker=178)
# Pandas(Index=242, ticker='GOLD', news_per_ticker=177)
# Pandas(Index=243, ticker='STX', news_per_ticker=177)
# Pandas(Index=244, ticker='HOG', news_per_ticker=175)
# Pandas(Index=245, ticker='CNMD', news_per_ticker=171)
# Pandas(Index=246, ticker='ILMN', news_per_ticker=171)
# Pandas(Index=247, ticker='MPC', news_per_ticker=171)
# Pandas(Index=248, ticker='BK', news_per_ticker=170)
# Pandas(Index=249, ticker='HPQ', news_per_ticker=170)
# Pandas(Index=250, ticker='SRE', news_per_ticker=169)
# Pandas(Index=251, ticker='CSX', news_per_ticker=169)
# Pandas(Index=252, ticker='TRV', news_per_ticker=169)
# Pandas(Index=253, ticker='LOW', news_per_ticker=168)
# Pandas(Index=254, ticker='CATM', news_per_ticker=166)
# Pandas(Index=255, ticker='MET', news_per_ticker=166)
# Pandas(Index=256, ticker='SPG', news_per_ticker=165)
# Pandas(Index=257, ticker='ALNY', news_per_ticker=164)
# Pandas(Index=258, ticker='CROX', news_per_ticker=164)
# Pandas(Index=259, ticker='RDY', news_per_ticker=163)
# Pandas(Index=260, ticker='TMO', news_per_ticker=163)
# Pandas(Index=261, ticker='NS', news_per_ticker=162)
# Pandas(Index=262, ticker='ITRI', news_per_ticker=161)
# Pandas(Index=263, ticker='LH', news_per_ticker=161)
# Pandas(Index=264, ticker='CASY', news_per_ticker=160)
# Pandas(Index=265, ticker='VIAC', news_per_ticker=159)
# Pandas(Index=266, ticker='AMP', news_per_ticker=159)
# Pandas(Index=267, ticker='AIMC', news_per_ticker=159)
# Pandas(Index=268, ticker='ADI', news_per_ticker=159)
# Pandas(Index=269, ticker='ETR', news_per_ticker=158)
# Pandas(Index=270, ticker='AVAV', news_per_ticker=157)
# Pandas(Index=271, ticker='CNS', news_per_ticker=156)
# Pandas(Index=272, ticker='MCK', news_per_ticker=156)
# Pandas(Index=273, ticker='AMT', news_per_ticker=155)
# Pandas(Index=274, ticker='GPC', news_per_ticker=154)
# Pandas(Index=275, ticker='CVS', news_per_ticker=154)
# Pandas(Index=276, ticker='VMC', news_per_ticker=153)
# Pandas(Index=277, ticker='CEF', news_per_ticker=153)
# Pandas(Index=278, ticker='LHX', news_per_ticker=153)
# Pandas(Index=279, ticker='RCI', news_per_ticker=152)
# Pandas(Index=280, ticker='HAL', news_per_ticker=151)
# Pandas(Index=281, ticker='RHI', news_per_ticker=151)
# Pandas(Index=282, ticker='HES', news_per_ticker=151)
# Pandas(Index=283, ticker='ADSK', news_per_ticker=150)
# Pandas(Index=284, ticker='LB', news_per_ticker=149)
# Pandas(Index=285, ticker='PLD', news_per_ticker=148)
# Pandas(Index=286, ticker='MUR', news_per_ticker=148)
# Pandas(Index=287, ticker='GPAGF', news_per_ticker=147)
# Pandas(Index=288, ticker='LUV', news_per_ticker=143)
# Pandas(Index=289, ticker='ARCH', news_per_ticker=142)
# Pandas(Index=290, ticker='KLAC', news_per_ticker=142)
# Pandas(Index=291, ticker='WPM', news_per_ticker=142)
# Pandas(Index=292, ticker='RS', news_per_ticker=142)
# Pandas(Index=293, ticker='CRUS', news_per_ticker=141)
# Pandas(Index=294, ticker='ANTM', news_per_ticker=141)
# Pandas(Index=295, ticker='SCCO', news_per_ticker=141)
# Pandas(Index=296, ticker='NTES', news_per_ticker=140)
# Pandas(Index=297, ticker='PAAS', news_per_ticker=140)
# Pandas(Index=298, ticker='TXN', news_per_ticker=139)
# Pandas(Index=299, ticker='VMW', news_per_ticker=138)
# Pandas(Index=300, ticker='AEIS', news_per_ticker=138)
# Pandas(Index=301, ticker='OXY', news_per_ticker=137)
# Pandas(Index=302, ticker='AAXN', news_per_ticker=136)
# Pandas(Index=303, ticker='MGA', news_per_ticker=136)
# Pandas(Index=304, ticker='GWW', news_per_ticker=136)
# Pandas(Index=305, ticker='CHEF', news_per_ticker=135)
# Pandas(Index=306, ticker='KMB', news_per_ticker=135)
# Pandas(Index=307, ticker='CSII', news_per_ticker=133)
# Pandas(Index=308, ticker='MRVL', news_per_ticker=132)
# Pandas(Index=309, ticker='SRPT', news_per_ticker=132)
# Pandas(Index=310, ticker='HSIC', news_per_ticker=131)
# Pandas(Index=311, ticker='TEX', news_per_ticker=131)
# Pandas(Index=312, ticker='OKE', news_per_ticker=130)
# Pandas(Index=313, ticker='IPG', news_per_ticker=130)
# Pandas(Index=314, ticker='DOV', news_per_ticker=129)
# Pandas(Index=315, ticker='ARGO', news_per_ticker=129)
# Pandas(Index=316, ticker='PCG', news_per_ticker=129)
# Pandas(Index=317, ticker='HRB', news_per_ticker=128)
# Pandas(Index=318, ticker='LNC', news_per_ticker=127)
# Pandas(Index=319, ticker='NTAP', news_per_ticker=126)
# Pandas(Index=320, ticker='AKAM', news_per_ticker=125)
# Pandas(Index=321, ticker='AMX', news_per_ticker=125)
# Pandas(Index=322, ticker='AON', news_per_ticker=125)
# Pandas(Index=323, ticker='IPGP', news_per_ticker=125)
# Pandas(Index=324, ticker='CDNS', news_per_ticker=124)
# Pandas(Index=325, ticker='BRKb', news_per_ticker=124)
# Pandas(Index=326, ticker='RYAAY', news_per_ticker=124)
# Pandas(Index=327, ticker='OSK', news_per_ticker=124)
# Pandas(Index=328, ticker='ORLY', news_per_ticker=124)
# Pandas(Index=329, ticker='ATVI', news_per_ticker=124)
# Pandas(Index=330, ticker='SSRM', news_per_ticker=124)
# Pandas(Index=331, ticker='ALL', news_per_ticker=124)
# Pandas(Index=332, ticker='HRL', news_per_ticker=123)
# Pandas(Index=333, ticker='CRAI', news_per_ticker=123)
# Pandas(Index=334, ticker='GT', news_per_ticker=123)
# Pandas(Index=335, ticker='CAG', news_per_ticker=122)
# Pandas(Index=336, ticker='PNW', news_per_ticker=121)
# Pandas(Index=337, ticker='CIEN', news_per_ticker=121)
# Pandas(Index=338, ticker='SPAR', news_per_ticker=120)
# Pandas(Index=339, ticker='JEF', news_per_ticker=120)
# Pandas(Index=340, ticker='FLS', news_per_ticker=120)
# Pandas(Index=341, ticker='DHR', news_per_ticker=120)
# Pandas(Index=342, ticker='LAZ', news_per_ticker=119)
# Pandas(Index=343, ticker='MHO', news_per_ticker=119)
# Pandas(Index=344, ticker='FLR', news_per_ticker=119)
# Pandas(Index=345, ticker='NRG', news_per_ticker=119)
# Pandas(Index=346, ticker='NBL', news_per_ticker=119)
# Pandas(Index=347, ticker='ATI', news_per_ticker=119)
# Pandas(Index=348, ticker='PKI', news_per_ticker=118)
# Pandas(Index=349, ticker='TPR', news_per_ticker=117)
# Pandas(Index=350, ticker='DXCM', news_per_ticker=117)
# Pandas(Index=351, ticker='ABMD', news_per_ticker=117)
# Pandas(Index=352, ticker='DISCA', news_per_ticker=116)
# Pandas(Index=353, ticker='WU', news_per_ticker=116)
# Pandas(Index=354, ticker='MOS', news_per_ticker=116)
# Pandas(Index=355, ticker='COG', news_per_ticker=116)
# Pandas(Index=356, ticker='CRI', news_per_ticker=116)
# Pandas(Index=357, ticker='CLX', news_per_ticker=115)
# Pandas(Index=358, ticker='LAMR', news_per_ticker=115)
# Pandas(Index=359, ticker='CORT', news_per_ticker=114)
# Pandas(Index=360, ticker='ADM', news_per_ticker=114)
# Pandas(Index=361, ticker='KYOCY', news_per_ticker=113)
# Pandas(Index=362, ticker='TROW', news_per_ticker=113)
# Pandas(Index=363, ticker='FLIR', news_per_ticker=113)
# Pandas(Index=364, ticker='PAYX', news_per_ticker=112)
# Pandas(Index=365, ticker='CHKP', news_per_ticker=112)
# Pandas(Index=366, ticker='NSC', news_per_ticker=111)
# Pandas(Index=367, ticker='L', news_per_ticker=111)
# Pandas(Index=368, ticker='MAS', news_per_ticker=111)
# Pandas(Index=369, ticker='TAP', news_per_ticker=111)
# Pandas(Index=370, ticker='PCAR', news_per_ticker=111)
# Pandas(Index=371, ticker='MAT', news_per_ticker=110)
# Pandas(Index=372, ticker='TFC', news_per_ticker=110)
# Pandas(Index=373, ticker='ATGE', news_per_ticker=108)
# Pandas(Index=374, ticker='DHI', news_per_ticker=108)
# Pandas(Index=375, ticker='FISV', news_per_ticker=107)
# Pandas(Index=376, ticker='AFL', news_per_ticker=107)
# Pandas(Index=377, ticker='CENT', news_per_ticker=106)
# Pandas(Index=378, ticker='CACC', news_per_ticker=106)
# Pandas(Index=379, ticker='PH', news_per_ticker=105)
# Pandas(Index=380, ticker='CBRL', news_per_ticker=104)
# Pandas(Index=381, ticker='IP', news_per_ticker=104)
# Pandas(Index=382, ticker='NOV', news_per_ticker=103)
# Pandas(Index=383, ticker='BDX', news_per_ticker=103)
# Pandas(Index=384, ticker='NXPI', news_per_ticker=103)
# Pandas(Index=385, ticker='HAIN', news_per_ticker=102)
# Pandas(Index=386, ticker='BMRN', news_per_ticker=101)
# Pandas(Index=387, ticker='MCHP', news_per_ticker=101)
# Pandas(Index=388, ticker='CECE', news_per_ticker=100)
# Pandas(Index=389, ticker='PSA', news_per_ticker=100)
# Pandas(Index=390, ticker='EMR', news_per_ticker=100)
# Pandas(Index=391, ticker='JCI', news_per_ticker=100)
# Pandas(Index=392, ticker='PFG', news_per_ticker=99)
# Pandas(Index=393, ticker='ACAD', news_per_ticker=99)
# Pandas(Index=394, ticker='PHM', news_per_ticker=99)
# Pandas(Index=395, ticker='LVS', news_per_ticker=99)
# Pandas(Index=396, ticker='HP', news_per_ticker=98)
# Pandas(Index=397, ticker='EMN', news_per_ticker=98)
# Pandas(Index=398, ticker='ROK', news_per_ticker=98)
# Pandas(Index=399, ticker='R', news_per_ticker=97)
# Pandas(Index=400, ticker='FIS', news_per_ticker=97)
# Pandas(Index=401, ticker='SYK', news_per_ticker=97)
# Pandas(Index=402, ticker='TECK', news_per_ticker=97)
# Pandas(Index=403, ticker='AEE', news_per_ticker=96)
# Pandas(Index=404, ticker='DENN', news_per_ticker=96)
# Pandas(Index=405, ticker='CERN', news_per_ticker=95)
# Pandas(Index=406, ticker='ARCB', news_per_ticker=95)
# Pandas(Index=407, ticker='IONS', news_per_ticker=95)
# Pandas(Index=408, ticker='SEE', news_per_ticker=95)
# Pandas(Index=409, ticker='FITB', news_per_ticker=94)
# Pandas(Index=410, ticker='VTR', news_per_ticker=94)
# Pandas(Index=411, ticker='WM', news_per_ticker=93)
# Pandas(Index=412, ticker='AES', news_per_ticker=92)
# Pandas(Index=413, ticker='WAT', news_per_ticker=92)
# Pandas(Index=414, ticker='OMC', news_per_ticker=92)
# Pandas(Index=415, ticker='AN', news_per_ticker=92)
# Pandas(Index=416, ticker='ARRY', news_per_ticker=91)
# Pandas(Index=417, ticker='CAH', news_per_ticker=91)
# Pandas(Index=418, ticker='CHDN', news_per_ticker=91)
# Pandas(Index=419, ticker='DDD', news_per_ticker=90)
# Pandas(Index=420, ticker='VNO', news_per_ticker=90)
# Pandas(Index=421, ticker='VRSN', news_per_ticker=90)
# Pandas(Index=422, ticker='TJX', news_per_ticker=90)
# Pandas(Index=423, ticker='ALKS', news_per_ticker=89)
# Pandas(Index=424, ticker='DXC', news_per_ticker=88)
# Pandas(Index=425, ticker='ZION', news_per_ticker=88)
# Pandas(Index=426, ticker='NCR', news_per_ticker=88)
# Pandas(Index=427, ticker='APOG', news_per_ticker=88)
# Pandas(Index=428, ticker='JNPR', news_per_ticker=87)
# Pandas(Index=429, ticker='PUMG', news_per_ticker=87)
# Pandas(Index=430, ticker='EIX', news_per_ticker=87)
# Pandas(Index=431, ticker='CRZO', news_per_ticker=87)
# Pandas(Index=432, ticker='CL', news_per_ticker=87)
# Pandas(Index=433, ticker='BSX', news_per_ticker=87)
# Pandas(Index=434, ticker='CRMT', news_per_ticker=86)
# Pandas(Index=435, ticker='SGEN', news_per_ticker=86)
# Pandas(Index=436, ticker='ALV', news_per_ticker=85)
# Pandas(Index=437, ticker='HIG', news_per_ticker=85)
# Pandas(Index=438, ticker='BEN', news_per_ticker=85)
# Pandas(Index=439, ticker='JBL', news_per_ticker=83)
# Pandas(Index=440, ticker='FFIV', news_per_ticker=83)
# Pandas(Index=441, ticker='JBHT', news_per_ticker=83)
# Pandas(Index=442, ticker='IFF', news_per_ticker=82)
# Pandas(Index=443, ticker='DFS', news_per_ticker=81)
# Pandas(Index=444, ticker='WY', news_per_ticker=81)
# Pandas(Index=445, ticker='ITW', news_per_ticker=81)
# Pandas(Index=446, ticker='CWST', news_per_ticker=80)
# Pandas(Index=447, ticker='MTW', news_per_ticker=80)
# Pandas(Index=448, ticker='BMS', news_per_ticker=80)
# Pandas(Index=449, ticker='D', news_per_ticker=80)
# Pandas(Index=450, ticker='ARNA', news_per_ticker=80)
# Pandas(Index=451, ticker='AMKR', news_per_ticker=79)
# Pandas(Index=452, ticker='ED', news_per_ticker=79)
# Pandas(Index=453, ticker='NWL', news_per_ticker=79)
# Pandas(Index=454, ticker='APLO', news_per_ticker=79)
# Pandas(Index=455, ticker='SINA', news_per_ticker=78)
# Pandas(Index=456, ticker='NIO', news_per_ticker=78)
# Pandas(Index=457, ticker='BECN', news_per_ticker=78)
# Pandas(Index=458, ticker='FAST', news_per_ticker=77)
# Pandas(Index=459, ticker='CBSH', news_per_ticker=77)
# Pandas(Index=460, ticker='SWK', news_per_ticker=77)
# Pandas(Index=461, ticker='ANGO', news_per_ticker=76)
# Pandas(Index=462, ticker='SRCL', news_per_ticker=76)
# Pandas(Index=463, ticker='DGX', news_per_ticker=76)
# Pandas(Index=464, ticker='COHR', news_per_ticker=75)
# Pandas(Index=465, ticker='MNST', news_per_ticker=75)
# Pandas(Index=466, ticker='BEAT', news_per_ticker=75)
# Pandas(Index=467, ticker='ZBH', news_per_ticker=74)
# Pandas(Index=468, ticker='CTSH', news_per_ticker=74)
# Pandas(Index=469, ticker='SNA', news_per_ticker=74)
# Pandas(Index=470, ticker='TV', news_per_ticker=74)
# Pandas(Index=471, ticker='AMSF', news_per_ticker=74)
# Pandas(Index=472, ticker='MGM', news_per_ticker=74)
# Pandas(Index=473, ticker='CTXS', news_per_ticker=73)
# Pandas(Index=474, ticker='AEP', news_per_ticker=73)
# Pandas(Index=475, ticker='EXC', news_per_ticker=73)
# Pandas(Index=476, ticker='AMTD', news_per_ticker=73)
# Pandas(Index=477, ticker='BLL', news_per_ticker=72)
# Pandas(Index=478, ticker='MRO', news_per_ticker=72)
# Pandas(Index=479, ticker='SLM', news_per_ticker=72)
# Pandas(Index=480, ticker='NWS', news_per_ticker=71)
# Pandas(Index=481, ticker='DCMYY', news_per_ticker=71)
# Pandas(Index=482, ticker='EQR', news_per_ticker=71)
# Pandas(Index=483, ticker='BOKF', news_per_ticker=69)
# Pandas(Index=484, ticker='ASB', news_per_ticker=69)
# Pandas(Index=485, ticker='LEG', news_per_ticker=69)
# Pandas(Index=486, ticker='CORE', news_per_ticker=69)
# Pandas(Index=487, ticker='TXT', news_per_ticker=69)
# Pandas(Index=488, ticker='BBQ', news_per_ticker=68)
# Pandas(Index=489, ticker='BOOM', news_per_ticker=68)
# Pandas(Index=490, ticker='AEGN', news_per_ticker=68)
# Pandas(Index=491, ticker='ACHC', news_per_ticker=67)
# Pandas(Index=492, ticker='PEAK', news_per_ticker=67)
# Pandas(Index=493, ticker='MMC', news_per_ticker=67)
# Pandas(Index=494, ticker='GLW', news_per_ticker=66)
# Pandas(Index=495, ticker='DOW', news_per_ticker=66)
# Pandas(Index=496, ticker='WELL', news_per_ticker=66)
# Pandas(Index=497, ticker='IAC', news_per_ticker=66)
# Pandas(Index=498, ticker='MDP', news_per_ticker=65)
# Pandas(Index=499, ticker='FE', news_per_ticker=65)
# Pandas(Index=500, ticker='ECL', news_per_ticker=65)
# Pandas(Index=501, ticker='MXIM', news_per_ticker=64)
# Pandas(Index=502, ticker='CTWS', news_per_ticker=64)
# Pandas(Index=503, ticker='SITC', news_per_ticker=63)
# Pandas(Index=504, ticker='LNN', news_per_ticker=63)
# Pandas(Index=505, ticker='ASR', news_per_ticker=63)
# Pandas(Index=506, ticker='BLDR', news_per_ticker=63)
# Pandas(Index=507, ticker='SNV', news_per_ticker=62)
# Pandas(Index=508, ticker='NTUS', news_per_ticker=62)
# Pandas(Index=509, ticker='IBN', news_per_ticker=62)
# Pandas(Index=510, ticker='USB', news_per_ticker=62)
# Pandas(Index=511, ticker='AIV', news_per_ticker=61)
# Pandas(Index=512, ticker='HOLX', news_per_ticker=61)
# Pandas(Index=513, ticker='CACH', news_per_ticker=61)
# Pandas(Index=514, ticker='CNP', news_per_ticker=61)
# Pandas(Index=515, ticker='WTRG', news_per_ticker=60)
# Pandas(Index=516, ticker='KIM', news_per_ticker=60)
# Pandas(Index=517, ticker='ES', news_per_ticker=60)
# Pandas(Index=518, ticker='CMS', news_per_ticker=59)
# Pandas(Index=519, ticker='RAMP', news_per_ticker=58)
# Pandas(Index=520, ticker='PDCO', news_per_ticker=58)
# Pandas(Index=521, ticker='ARQL', news_per_ticker=58)
# Pandas(Index=522, ticker='CARB', news_per_ticker=58)
# Pandas(Index=523, ticker='CAKE', news_per_ticker=58)
# Pandas(Index=524, ticker='AFSIM', news_per_ticker=58)
# Pandas(Index=525, ticker='XRAY', news_per_ticker=58)
# Pandas(Index=526, ticker='AGNC', news_per_ticker=58)
# Pandas(Index=527, ticker='KOF', news_per_ticker=58)
# Pandas(Index=528, ticker='ANDE', news_per_ticker=57)
# Pandas(Index=529, ticker='APH', news_per_ticker=57)
# Pandas(Index=530, ticker='APEI', news_per_ticker=57)
# Pandas(Index=531, ticker='DCIX', news_per_ticker=57)
# Pandas(Index=532, ticker='AMWD', news_per_ticker=57)
# Pandas(Index=533, ticker='CLMT', news_per_ticker=57)
# Pandas(Index=534, ticker='DVA', news_per_ticker=56)
# Pandas(Index=535, ticker='VFC', news_per_ticker=56)
# Pandas(Index=536, ticker='SOHU', news_per_ticker=56)
# Pandas(Index=537, ticker='IRM', news_per_ticker=55)
# Pandas(Index=538, ticker='ITT', news_per_ticker=55)
# Pandas(Index=539, ticker='UIS', news_per_ticker=55)
# Pandas(Index=540, ticker='MTG', news_per_ticker=55)
# Pandas(Index=541, ticker='CLFD', news_per_ticker=55)
# Pandas(Index=542, ticker='KDP', news_per_ticker=54)
# Pandas(Index=543, ticker='EPAC', news_per_ticker=54)
# Pandas(Index=544, ticker='ANSS', news_per_ticker=54)
# Pandas(Index=545, ticker='HBAN', news_per_ticker=54)
# Pandas(Index=546, ticker='ASH', news_per_ticker=54)
# Pandas(Index=547, ticker='AAWW', news_per_ticker=53)
# Pandas(Index=548, ticker='CREE', news_per_ticker=53)
# Pandas(Index=549, ticker='FHN', news_per_ticker=52)
# Pandas(Index=550, ticker='RF', news_per_ticker=52)
# Pandas(Index=551, ticker='ACLS', news_per_ticker=51)
# Pandas(Index=552, ticker='CLAR', news_per_ticker=51)
# Pandas(Index=553, ticker='CALM', news_per_ticker=51)
# Pandas(Index=554, ticker='CCOI', news_per_ticker=50)
# Pandas(Index=555, ticker='BSTC', news_per_ticker=50)
# Pandas(Index=556, ticker='OI', news_per_ticker=49)
# Pandas(Index=557, ticker='DIOD', news_per_ticker=48)
# Pandas(Index=558, ticker='MIDD', news_per_ticker=48)
# Pandas(Index=559, ticker='UNM', news_per_ticker=48)
# Pandas(Index=560, ticker='ARWR', news_per_ticker=47)
# Pandas(Index=561, ticker='ASGN', news_per_ticker=46)
# Pandas(Index=562, ticker='CMCO', news_per_ticker=46)
# Pandas(Index=563, ticker='TER', news_per_ticker=46)
# Pandas(Index=564, ticker='ASTE', news_per_ticker=46)
# Pandas(Index=565, ticker='CRAY', news_per_ticker=45)
# Pandas(Index=566, ticker='TDC', news_per_ticker=45)
# Pandas(Index=567, ticker='PEG', news_per_ticker=45)
# Pandas(Index=568, ticker='RSG', news_per_ticker=45)
# Pandas(Index=569, ticker='SSP', news_per_ticker=45)
# Pandas(Index=570, ticker='EBIX', news_per_ticker=45)
# Pandas(Index=571, ticker='DXLG', news_per_ticker=44)
# Pandas(Index=572, ticker='HDB', news_per_ticker=43)
# Pandas(Index=573, ticker='CCEP', news_per_ticker=43)
# Pandas(Index=574, ticker='COHU', news_per_ticker=43)
# Pandas(Index=575, ticker='CASH', news_per_ticker=43)
# Pandas(Index=576, ticker='HOV', news_per_ticker=43)
# Pandas(Index=577, ticker='HST', news_per_ticker=42)
# Pandas(Index=578, ticker='BLDP', news_per_ticker=41)
# Pandas(Index=579, ticker='COKE', news_per_ticker=40)
# Pandas(Index=580, ticker='IR', news_per_ticker=40)
# Pandas(Index=581, ticker='IX', news_per_ticker=39)
# Pandas(Index=582, ticker='ACIW', news_per_ticker=39)
# Pandas(Index=583, ticker='CYTR', news_per_ticker=39)
# Pandas(Index=584, ticker='DGICA', news_per_ticker=39)
# Pandas(Index=585, ticker='CHRS', news_per_ticker=38)
# Pandas(Index=586, ticker='CVGW', news_per_ticker=38)
# Pandas(Index=587, ticker='CVTI', news_per_ticker=38)
# Pandas(Index=588, ticker='NTTYY', news_per_ticker=37)
# Pandas(Index=589, ticker='ATNI', news_per_ticker=37)
# Pandas(Index=590, ticker='AUDC', news_per_ticker=37)
# Pandas(Index=591, ticker='AX', news_per_ticker=37)
# Pandas(Index=592, ticker='NI', news_per_ticker=37)
# Pandas(Index=593, ticker='AOSL', news_per_ticker=37)
# Pandas(Index=594, ticker='BFb', news_per_ticker=36)
# Pandas(Index=595, ticker='CYOU', news_per_ticker=36)
# Pandas(Index=596, ticker='CWCO', news_per_ticker=35)
# Pandas(Index=597, ticker='CCRN', news_per_ticker=35)
# Pandas(Index=598, ticker='ECPG', news_per_ticker=35)
# Pandas(Index=599, ticker='DCTHD', news_per_ticker=35)
# Pandas(Index=600, ticker='MANT', news_per_ticker=34)
# Pandas(Index=601, ticker='CHRW', news_per_ticker=34)
# Pandas(Index=602, ticker='AMOT', news_per_ticker=34)
# Pandas(Index=603, ticker='BRKS', news_per_ticker=33)
# Pandas(Index=604, ticker='BC', news_per_ticker=33)
# Pandas(Index=605, ticker='VCEL', news_per_ticker=33)
# Pandas(Index=606, ticker='KEY', news_per_ticker=33)
# Pandas(Index=607, ticker='CYTK', news_per_ticker=33)
# Pandas(Index=608, ticker='PIPR', news_per_ticker=33)
# Pandas(Index=609, ticker='IGT', news_per_ticker=32)
# Pandas(Index=610, ticker='CEVA', news_per_ticker=32)
# Pandas(Index=611, ticker='IVZ', news_per_ticker=32)
# Pandas(Index=612, ticker='ADUS', news_per_ticker=32)
# Pandas(Index=613, ticker='BANF', news_per_ticker=32)
# Pandas(Index=614, ticker='PRDO', news_per_ticker=31)
# Pandas(Index=615, ticker='CSGP', news_per_ticker=31)
# Pandas(Index=616, ticker='NUAN', news_per_ticker=31)
# Pandas(Index=617, ticker='VIAV', news_per_ticker=31)
# Pandas(Index=618, ticker='WEC', news_per_ticker=30)
# Pandas(Index=619, ticker='CGNX', news_per_ticker=30)
# Pandas(Index=620, ticker='CAMT', news_per_ticker=30)
# Pandas(Index=621, ticker='CTRN', news_per_ticker=29)
# Pandas(Index=622, ticker='CY', news_per_ticker=29)
# Pandas(Index=623, ticker='PPL', news_per_ticker=29)
# Pandas(Index=624, ticker='EBMT', news_per_ticker=28)
# Pandas(Index=625, ticker='OPCH', news_per_ticker=28)
# Pandas(Index=626, ticker='BBSI', news_per_ticker=28)
# Pandas(Index=627, ticker='DGII', news_per_ticker=28)
# Pandas(Index=628, ticker='ASFI', news_per_ticker=27)
# Pandas(Index=629, ticker='TCOM', news_per_ticker=27)
# Pandas(Index=630, ticker='CIM', news_per_ticker=26)
# Pandas(Index=631, ticker='AAON', news_per_ticker=26)
# Pandas(Index=632, ticker='CPSI', news_per_ticker=25)
# Pandas(Index=633, ticker='CAAS', news_per_ticker=25)
# Pandas(Index=634, ticker='KNMCY', news_per_ticker=25)
# Pandas(Index=635, ticker='CCMP', news_per_ticker=25)
# Pandas(Index=636, ticker='BSET', news_per_ticker=25)
# Pandas(Index=637, ticker='BMRC', news_per_ticker=25)
# Pandas(Index=638, ticker='ECOL', news_per_ticker=24)
# Pandas(Index=639, ticker='BSPM', news_per_ticker=23)
# Pandas(Index=640, ticker='GRBK', news_per_ticker=23)
# Pandas(Index=641, ticker='ENTG', news_per_ticker=23)
# Pandas(Index=642, ticker='ATRO', news_per_ticker=23)
# Pandas(Index=643, ticker='RDWR', news_per_ticker=22)
# Pandas(Index=644, ticker='CGEN', news_per_ticker=22)
# Pandas(Index=645, ticker='FANH', news_per_ticker=22)
# Pandas(Index=646, ticker='MPAA', news_per_ticker=21)
# Pandas(Index=647, ticker='CUTR', news_per_ticker=21)
# Pandas(Index=648, ticker='DORM', news_per_ticker=21)
# Pandas(Index=649, ticker='CSOD', news_per_ticker=20)
# Pandas(Index=650, ticker='CNET', news_per_ticker=20)
# Pandas(Index=651, ticker='ADTN', news_per_ticker=20)
# Pandas(Index=652, ticker='BOCH', news_per_ticker=20)
# Pandas(Index=653, ticker='BWEN', news_per_ticker=20)
# Pandas(Index=654, ticker='ALBO', news_per_ticker=19)
# Pandas(Index=655, ticker='CPL', news_per_ticker=19)
# Pandas(Index=656, ticker='CHCO', news_per_ticker=18)
# Pandas(Index=657, ticker='CAC', news_per_ticker=18)
# Pandas(Index=658, ticker='CYBE', news_per_ticker=18)
# Pandas(Index=659, ticker='CARV', news_per_ticker=18)
# Pandas(Index=660, ticker='DSG', news_per_ticker=17)
# Pandas(Index=661, ticker='DXYN', news_per_ticker=17)
# Pandas(Index=662, ticker='ECHO', news_per_ticker=17)
# Pandas(Index=663, ticker='THRM', news_per_ticker=17)
# Pandas(Index=664, ticker='ARTX', news_per_ticker=17)
# Pandas(Index=665, ticker='CCNE', news_per_ticker=16)
# Pandas(Index=666, ticker='PME', news_per_ticker=16)
# Pandas(Index=667, ticker='BANR', news_per_ticker=16)
# Pandas(Index=668, ticker='BLKB', news_per_ticker=16)
# Pandas(Index=669, ticker='ABCB', news_per_ticker=16)
# Pandas(Index=670, ticker='TAOP', news_per_ticker=15)
# Pandas(Index=671, ticker='STC', news_per_ticker=15)
# Pandas(Index=672, ticker='CSFL', news_per_ticker=15)
# Pandas(Index=673, ticker='CALI', news_per_ticker=15)
# Pandas(Index=674, ticker='CCBG', news_per_ticker=15)
# Pandas(Index=675, ticker='CNTFY', news_per_ticker=15)
# Pandas(Index=676, ticker='RMBS', news_per_ticker=14)
# Pandas(Index=677, ticker='CPIX', news_per_ticker=14)
# Pandas(Index=678, ticker='BANC', news_per_ticker=14)
# Pandas(Index=679, ticker='AMRB', news_per_ticker=14)
# Pandas(Index=680, ticker='CATY', news_per_ticker=14)
# Pandas(Index=681, ticker='CSGS', news_per_ticker=14)
# Pandas(Index=682, ticker='DMRC', news_per_ticker=13)
# Pandas(Index=683, ticker='BPFH', news_per_ticker=13)
# Pandas(Index=684, ticker='CDXS', news_per_ticker=13)
# Pandas(Index=685, ticker='CETV', news_per_ticker=13)
# Pandas(Index=686, ticker='CRWS', news_per_ticker=13)
# Pandas(Index=687, ticker='IBA', news_per_ticker=13)
# Pandas(Index=688, ticker='BCBP', news_per_ticker=13)
# Pandas(Index=689, ticker='ARTNA', news_per_ticker=13)
# Pandas(Index=690, ticker='CASS', news_per_ticker=12)
# Pandas(Index=691, ticker='AMNB', news_per_ticker=12)
# Pandas(Index=692, ticker='BDGE', news_per_ticker=12)
# Pandas(Index=693, ticker='BFIN', news_per_ticker=12)
# Pandas(Index=694, ticker='FLEX', news_per_ticker=12)
# Pandas(Index=695, ticker='CTBI', news_per_ticker=12)
# Pandas(Index=696, ticker='ALOT', news_per_ticker=11)
# Pandas(Index=697, ticker='BVSN', news_per_ticker=11)
# Pandas(Index=698, ticker='ADES', news_per_ticker=11)
# Pandas(Index=699, ticker='CLCT', news_per_ticker=11)
# Pandas(Index=700, ticker='AGYS', news_per_ticker=11)
# Pandas(Index=701, ticker='CPSS', news_per_ticker=11)
# Pandas(Index=702, ticker='DSPG', news_per_ticker=11)
# Pandas(Index=703, ticker='TRCB', news_per_ticker=10)
# Pandas(Index=704, ticker='IIJIY', news_per_ticker=10)
# Pandas(Index=705, ticker='DRAD', news_per_ticker=10)
# Pandas(Index=706, ticker='GHC', news_per_ticker=10)
# Pandas(Index=707, ticker='CPLP', news_per_ticker=10)
# Pandas(Index=708, ticker='CVCY', news_per_ticker=10)
# Pandas(Index=709, ticker='BSRR', news_per_ticker=10)
# Pandas(Index=710, ticker='DUSA', news_per_ticker=10)
# Pandas(Index=711, ticker='BMTC', news_per_ticker=9)
# Pandas(Index=712, ticker='AVNW', news_per_ticker=9)
# Pandas(Index=713, ticker='BSQR', news_per_ticker=9)
# Pandas(Index=714, ticker='CYAN', news_per_ticker=9)
# Pandas(Index=715, ticker='CBAT', news_per_ticker=9)
# Pandas(Index=716, ticker='COWN', news_per_ticker=9)
# Pandas(Index=717, ticker='CVCO', news_per_ticker=8)
# Pandas(Index=718, ticker='BCPC', news_per_ticker=8)
# Pandas(Index=719, ticker='DCOM', news_per_ticker=8)
# Pandas(Index=720, ticker='HOPE', news_per_ticker=8)
# Pandas(Index=721, ticker='DNBF', news_per_ticker=8)
# Pandas(Index=722, ticker='DAIO', news_per_ticker=8)
# Pandas(Index=723, ticker='AMSWA', news_per_ticker=7)
# Pandas(Index=724, ticker='DWSN', news_per_ticker=7)
# Pandas(Index=725, ticker='DYNT', news_per_ticker=7)
# Pandas(Index=726, ticker='ATRC', news_per_ticker=7)
# Pandas(Index=727, ticker='CBPO', news_per_ticker=7)
# Pandas(Index=728, ticker='BHLB', news_per_ticker=7)
# Pandas(Index=729, ticker='CIDM', news_per_ticker=7)
# Pandas(Index=730, ticker='DGICB', news_per_ticker=6)
# Pandas(Index=731, ticker='BRKL', news_per_ticker=6)
# Pandas(Index=732, ticker='ARLP', news_per_ticker=6)
# Pandas(Index=733, ticker='CHOPF', news_per_ticker=6)
# Pandas(Index=734, ticker='CBBI', news_per_ticker=6)
# Pandas(Index=735, ticker='CSPI', news_per_ticker=6)
# Pandas(Index=736, ticker='ALLT', news_per_ticker=6)
# Pandas(Index=737, ticker='EP_pc', news_per_ticker=6)
# Pandas(Index=738, ticker='BRID', news_per_ticker=5)
# Pandas(Index=739, ticker='ARKR', news_per_ticker=5)
# Pandas(Index=740, ticker='CLSN', news_per_ticker=5)
# Pandas(Index=741, ticker='CFFN', news_per_ticker=5)
# Pandas(Index=742, ticker='DJCO', news_per_ticker=5)
# Pandas(Index=743, ticker='EBSB', news_per_ticker=5)
# Pandas(Index=744, ticker='MITSY', news_per_ticker=5)
# Pandas(Index=745, ticker='BYFC', news_per_ticker=5)
# Pandas(Index=746, ticker='COLB', news_per_ticker=5)
# Pandas(Index=747, ticker='BOSC', news_per_ticker=5)
# Pandas(Index=748, ticker='CGA', news_per_ticker=5)
# Pandas(Index=749, ticker='ANAT', news_per_ticker=4)
# Pandas(Index=750, ticker='CNBKA', news_per_ticker=4)
# Pandas(Index=751, ticker='ATRI', news_per_ticker=4)
# Pandas(Index=752, ticker='DSWL', news_per_ticker=4)
# Pandas(Index=753, ticker='BKSC', news_per_ticker=4)
# Pandas(Index=754, ticker='HKTVY', news_per_ticker=4)
# Pandas(Index=755, ticker='CFFI', news_per_ticker=4)
# Pandas(Index=756, ticker='CFBK', news_per_ticker=4)
# Pandas(Index=757, ticker='CLRO', news_per_ticker=4)
# Pandas(Index=758, ticker='CNAF', news_per_ticker=4)
# Pandas(Index=759, ticker='CSWC', news_per_ticker=4)
# Pandas(Index=760, ticker='DISCK', news_per_ticker=4)
# Pandas(Index=761, ticker='MKTAY', news_per_ticker=4)
# Pandas(Index=762, ticker='ATLC', news_per_ticker=4)
# Pandas(Index=763, ticker='PTVCB', news_per_ticker=3)
# Pandas(Index=764, ticker='CPHC', news_per_ticker=3)
# Pandas(Index=765, ticker='SRL', news_per_ticker=3)
# Pandas(Index=766, ticker='AXTI', news_per_ticker=3)
# Pandas(Index=767, ticker='IRCP', news_per_ticker=3)
# Pandas(Index=768, ticker='CVBF', news_per_ticker=3)
# Pandas(Index=769, ticker='AROW', news_per_ticker=3)
# Pandas(Index=770, ticker='CTHR', news_per_ticker=3)
# Pandas(Index=771, ticker='BCOM', news_per_ticker=3)
# Pandas(Index=772, ticker='CWBC', news_per_ticker=3)
# Pandas(Index=773, ticker='DYSL', news_per_ticker=3)
# Pandas(Index=774, ticker='ALCO', news_per_ticker=2)
# Pandas(Index=775, ticker='AIRT', news_per_ticker=2)
# Pandas(Index=776, ticker='VIEWF', news_per_ticker=2)
# Pandas(Index=777, ticker='EQT', news_per_ticker=2)
# Pandas(Index=778, ticker='BERK', news_per_ticker=2)
# Pandas(Index=779, ticker='FHI', news_per_ticker=2)
# Pandas(Index=780, ticker='AUBN', news_per_ticker=2)
# Pandas(Index=781, ticker='CVLY', news_per_ticker=2)
# Pandas(Index=782, ticker='CVV', news_per_ticker=2)
# Pandas(Index=783, ticker='CZFC', news_per_ticker=2)
# Pandas(Index=784, ticker='BELFB', news_per_ticker=2)
# Pandas(Index=785, ticker='CBAN', news_per_ticker=2)
# Pandas(Index=786, ticker='DISCB', news_per_ticker=2)
# Pandas(Index=787, ticker='CENTA', news_per_ticker=2)
# Pandas(Index=788, ticker='BNSO', news_per_ticker=2)
# Pandas(Index=789, ticker='CCUR', news_per_ticker=2)
# Pandas(Index=790, ticker='EDMCQ', news_per_ticker=1)
# Pandas(Index=791, ticker='CZNC', news_per_ticker=1)
# Pandas(Index=792, ticker='DMLP', news_per_ticker=1)
# Pandas(Index=793, ticker='CFNB', news_per_ticker=1)
# Pandas(Index=794, ticker='ATLO', news_per_ticker=1)
# Pandas(Index=795, ticker='CART', news_per_ticker=1)
# Pandas(Index=796, ticker='CHCI', news_per_ticker=1)
# Pandas(Index=797, ticker='BUSE', news_per_ticker=1)
# Pandas(Index=798, ticker='EBTC', news_per_ticker=1)
# Pandas(Index=799, ticker='CRMBQ', news_per_ticker=1)
# Pandas(Index=800, ticker='BELFA', news_per_ticker=1)
# Pandas(Index=801, ticker='CIZN', news_per_ticker=1)

# %%
news_per_ticker_count_filter = news_per_ticker_count[news_per_ticker_count["news_per_ticker"] >= 2500]

# %%
news_per_ticker_count_filter
# Out:
#    ticker  news_per_ticker
# 0    AAPL            20231
# 1    MSFT             8110
# 2     BAC             7408
# 3    AMZN             6330
# 4    NWSA             5914
# 5      BA             5879
# 6   GOOGL             5171
# 7      GS             4513
# 8    TSLA             4283
# 9    NFLX             3806
# 10    TGT             3689
# 11   INTC             3188
# 12    DIS             2875
# 13    XOM             2831
# 14    JPM             2600

# %%
plt.figure(figsize=(50,50))

plt.xlabel('ticker')
plt.ylabel('news_per_ticker')

ax = sns.barplot(x="ticker", y="news_per_ticker", palette="pastel", edgecolor=".6", data=news_per_ticker_count_filter)
ax.bar_label(ax.containers[0])
sns.despine()

# %% [markdown]
# # Cantidad de noticias por ticker y por año

# %%
group_by_df = new_df.copy()

# %%
group_by_df = group_by_df[(df["ticker"]=="AAPL") | (df["ticker"]=="MSFT")].groupby(['ticker','release_date_year']).size().reset_index(name='counts_news')
sort_group_by_df = group_by_df.copy()
sort_group_by_df = sort_group_by_df.sort_values(by=['release_date_year'], ascending=True)
sort_group_by_df = sort_group_by_df.reset_index(drop=True)

# %%
sort_group_by_df
# Out:
#    ticker  release_date_year  counts_news
# 0    MSFT               2008            5
# 1    MSFT               2009           66
# 2    MSFT               2010            1
# 3    MSFT               2011           37
# 4    MSFT               2012           99
# 5    AAPL               2012          264
# 6    AAPL               2013          484
# 7    MSFT               2013          168
# 8    AAPL               2014          720
# 9    MSFT               2014          163
# 10   AAPL               2015         1481
# 11   MSFT               2015          486
# 12   AAPL               2016         2216
# 13   MSFT               2016          848
# 14   MSFT               2017         1238
# 15   AAPL               2017         5308
# 16   AAPL               2018         4300
# 17   MSFT               2018         1154
# 18   AAPL               2019         4881
# 19   MSFT               2019         3499
# 20   AAPL               2020          577
# 21   MSFT               2020          346

# %%
#set seaborn plotting aesthetics
plt.figure(figsize=(50,50))

plt.xlabel('release_date_year')
plt.ylabel('counts_news')

#create grouped bar chart
ax = sns.barplot(x='release_date_year', y='counts_news', hue='ticker', palette="pastel", edgecolor=".6", data=sort_group_by_df[sort_group_by_df.release_date_year > 2011], errwidth=0)

# ax.bar_label(ax.containers[0])

for i in ax.containers:

  ax.bar_label(i,)
    
sns.despine()

# Create datasets

# %% [markdown]
# # Frecuencia de las palabras

# %%
# Importo las librerías necesarias para procesar los textos
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize

import re

SPECIAL_CHARACTERS = []

SPECIAL_CHARACTERS.extend(map(chr, range(0, 32)))
SPECIAL_CHARACTERS.extend(map(chr, range(33, 48)))
SPECIAL_CHARACTERS.extend(map(chr, range(58, 65)))
SPECIAL_CHARACTERS.extend(map(chr, range(91, 97)))
SPECIAL_CHARACTERS.extend(map(chr, range(123, 225)))
SPECIAL_CHARACTERS.extend(map(chr, range(226, 233)))
SPECIAL_CHARACTERS.extend(map(chr, range(234, 237)))
SPECIAL_CHARACTERS.extend(map(chr, range(238, 241)))
SPECIAL_CHARACTERS.extend(map(chr, range(242, 243)))
SPECIAL_CHARACTERS.extend(map(chr, range(244, 250)))
SPECIAL_CHARACTERS.extend(map(chr, range(251, 880)))

# %%
class CleanText():
    
    def __init__(self, text, language="english"):
        
        self.text = text
        
        self.language = language
        
        self.clean_text = None
        
        self.remove_spec_text = None
        
        self.remove_stop_text = None
        
        self.lemma_text = None
    
    def removePatterns(self):
        
        replacements = (
            ("á", "a"),
            ("é", "e"),
            ("í", "i"),
            ("ó", "o"),
            ("ú", "u"),
        )
        
        self.text = str(self.text)
        
        self.clean_text = self.text.lower()
        
        self.clean_text = re.sub(r"\s{2,}", " ", self.clean_text)
        
        self.clean_text = re.sub(r"\n", " ", self.clean_text)
        
        self.clean_text = re.sub(r"\d+", " ", self.clean_text)
        
        self.clean_text = re.sub(r"^\s+", " ", self.clean_text)
        
        self.clean_text = re.sub(r"\s+", " ", self.clean_text)
        
        for a, b in replacements:
            
            self.clean_text = self.clean_text.replace(a, b).replace(a.upper(), b.upper())
        
        return self.clean_text
    
    def removeSpecChars(self):
        
        remove_patterns = self.removePatterns()
        
        tokens = list(word_tokenize(remove_patterns))
        
        clean_tokens = tokens.copy()
        
        for i in range(len(clean_tokens)):
            
            for special_character in SPECIAL_CHARACTERS:
            
                clean_tokens[i] = clean_tokens[i].replace(special_character, '')            
            
        clean_tokens = [token for token in clean_tokens if token]        
        
        self.remove_spec_text = " ".join(clean_tokens)        
        
        return self.remove_spec_text       
    
    def RemoveStopText(self):
        
        st = ["'", "!", '"', "#", "$", "%", "&", "*", "+", "-", ".", "/", "<", "=", '>', "?",
          "@", "[", "\\", "]", "^", "_", '`', "{", "|", "}", '~']
        
        sw = stopwords.words(self.language) + st
        
        text = list(word_tokenize(self.removeSpecChars()))
        
        text = [w for w in text if not w in sw]
        
        self.remove_stop_text = " ".join(text)
        
        return self.remove_stop_text
    
    def lemmatizeText(self):
        
        lemmatizer = WordNetLemmatizer()
        
        list_lemma_text = []
        
        tokens = word_tokenize(self.RemoveStopText())
        
        for token in tokens:
            
            lemmetized_word = lemmatizer.lemmatize(token)
            
            list_lemma_text.append(lemmetized_word)
        
        self.lemma_text = " ".join(list_lemma_text)
        
        return self.lemma_text

# %%
# new_df["clean_content"] = new_df["content"].map(lambda x: CleanText(str(x)).lemmatizeText())

# %%
# new_df["clean_title"] = new_df["title"].map(lambda x: CleanText(str(x)).lemmatizeText())

# %%
# load dataset
new_df = pd.read_csv(os.path.join(os.getcwd(), "data", "clean_news_dataset_v2.csv"))

# %%
new_df.head(5)
# Out:
#        id ticker                                              title category  \
# 0  221515    NIO  Why Shares of Chinese Electric Car Maker NIO A...     news
# 1  221516    NIO  NIO only consumer gainer  Workhorse Group amon...     news
# 2  221517    NIO  NIO leads consumer gainers  Beyond Meat and Ma...     news
# 3  221518    NIO                  NIO  NVAX among premarket gainers     news
# 4  221519    NIO                  PLUG  NIO among premarket gainers     news
#
#                                              content release_date  \
# 0  What s happening\nShares of Chinese electric c...   2020-01-15
# 1  Gainers  NIO  NYSE NIO   7  \nLosers  MGP Ingr...   2020-01-18
# 2  Gainers  NIO  NYSE NIO   14   Village Farms In...   2020-01-15
# 3  Cemtrex  NASDAQ CETX   85  after FY results \n...   2020-01-15
# 4  aTyr Pharma  NASDAQ LIFE   63  on Kyorin Pharm...   2020-01-06
#
#           provider                                                url  \
# 0  The Motley Fool                             https://invst.ly/pigqi
# 1    Seeking Alpha                             https://invst.ly/pje9c
# 2    Seeking Alpha                             https://invst.ly/pifmv
# 3    Seeking Alpha                             https://invst.ly/picu8
# 4    Seeking Alpha  https://seekingalpha.com/news/3529772-plug-nio...
#
#    article_id  release_date_year  \
# 0     2060327               2020
# 1     2062196               2020
# 2     2060249               2020
# 3     2060039               2020
# 4     2053096               2020
#
#                                        clean_content  \
# 0  happening share chinese electric car maker nio...
# 1  gainer nio nyse nio loser mgp ingredient nasda...
# 2  gainer nio nyse nio village farm international...
# 3  cemtrex nasdaq cetx fy result fluent nasdaq fl...
# 4  atyr pharma nasdaq life kyorin pharma deal tow...
#
#                                          clean_title
# 0  share chinese electric car maker nio flying hi...
# 1    nio consumer gainer workhorse group among loser
# 2  nio lead consumer gainer beyond meat mattel am...
# 3                    nio nvax among premarket gainer
# 4                    plug nio among premarket gainer

# %% [markdown]
# # Palabras más frecuentes

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
df_test = new_df.copy()

# %%
df_test.shape
# Out:
# (221513, 12)

# %%
cv = CountVectorizer()
sum_words_with_clean = cv.fit_transform(df_test['clean_content'].values.astype('U')).sum(axis=0)

# Calculamos 
words_freq_with_clean = [(word, sum_words_with_clean[0, idx]) for word, idx in cv.vocabulary_.items()]
words_freq_with_clean = sorted(words_freq_with_clean, key = lambda x: x[1], reverse=True)[:20]

# %%
sns.set(font_scale=1)

plt.figure(figsize=(7, 5))
plt.barh(*zip(*words_freq_with_clean))

plt.show()

# %% [markdown]
# # Merge "title" with "content" and "clean_title" with "clean_content"

# %%
sum_words_with_clean_title = cv.fit_transform((df_test["clean_title"] + df_test["clean_content"]).values.astype('U')).sum(axis=0)

# Calculamos 
words_freq_with_clean_title = [(word, sum_words_with_clean_title[0, idx]) for word, idx in cv.vocabulary_.items()]
words_freq_with_clean_title = sorted(words_freq_with_clean_title, key = lambda x: x[1], reverse=True)[:20]

# %%
sns.set(font_scale=1)

plt.figure(figsize=(7, 5))
plt.barh(*zip(*words_freq_with_clean_title))

plt.show()

# %% [markdown]
# # Clean Title

# %%
cv = CountVectorizer()
sum_words_only_title = cv.fit_transform(df_test['clean_title'].values.astype('U')).sum(axis=0)

# Calculamos 
words_freq_only_title = [(word, sum_words_only_title[0, idx]) for word, idx in cv.vocabulary_.items()]
words_freq_only_title = sorted(words_freq_only_title, key = lambda x: x[1], reverse=True)[:20]

# %%
sns.set(font_scale=1)

plt.figure(figsize=(7, 5))
plt.barh(*zip(*words_freq_only_title))

plt.show()

# %% [markdown]
# # El fin de este dataset es predecir si el label es opinion o news

# %%
df_test.category.value_counts()
# Out:
# opinion    125935
# news        95578
# Name: category, dtype: int64

# %%
df_category = new_df.copy()

df_opinion = df_category[df_category.category == "opinion"]
df_news = df_category[df_category.category == "news"]

# %%
# Se ve cuales son las palabras mas frecuentes en la category == opinion
sum_words_opinion = cv.fit_transform(df_opinion['clean_content'].values.astype('U')).sum(axis=0)

# Calculamos 
words_freq_opinion = [(word, sum_words_opinion[0, idx]) for word, idx in cv.vocabulary_.items()]
words_freq_opinion = sorted(words_freq_opinion, key = lambda x: x[1], reverse=True)[:20]

sns.set(font_scale=1)

plt.figure(figsize=(7, 5))
plt.barh(*zip(*words_freq_opinion))

plt.show()

# %%
# Se ve cuales son las palabras mas frecuentes en la category == news
sum_words_news = cv.fit_transform(df_news['clean_content'].values.astype('U')).sum(axis=0)

# Calculamos 
words_freq_news = [(word, sum_words_news[0, idx]) for word, idx in cv.vocabulary_.items()]
words_freq_news = sorted(words_freq_news, key = lambda x: x[1], reverse=True)[:20]

sns.set(font_scale=1)

plt.figure(figsize=(7, 5))
plt.barh(*zip(*words_freq_news))

plt.show()

# %% [markdown]
# # Se investiga cuales son las palabras unicas de la categoría de opinion y de news

# %%
list_word_opinion = [x[0] for x in words_freq_opinion]
list_word_news = [y[0] for y in words_freq_news]

# %%
unique_word_opinion = [x for x in list_word_opinion if x not in list_word_news]
unique_word_news = [x for x in list_word_news if x not in list_word_opinion]

# %%
print(unique_word_opinion)
print(unique_word_news)
# Out:
# ['zacks', 'earnings', 'quarter', 'estimate', 'growth', 'rank', 'revenue', 'price', 'consensus', 'investor']
# ['said', 'percent', 'new', 'would', 'reuters', 'bank', 'last', 'inc', 'point', 'trade']

# %% [markdown]
# # Se observan los bigrams y trigrams más frecuentes

# %%
cv_bigram = CountVectorizer(ngram_range=(2, 2))

# Se ve cuales son las palabras mas frecuentes en la category == opinion
sum_bigram_opinion = cv_bigram.fit_transform(df_opinion['clean_content'].values.astype('U')).sum(axis=0)

# Calculamos 
words_bigram_opinion = [(word, sum_bigram_opinion[0, idx]) for word, idx in cv_bigram.vocabulary_.items()]
words_bigram_opinion = sorted(words_bigram_opinion, key = lambda x: x[1], reverse=True)[:20]

sns.set(font_scale=1)

plt.figure(figsize=(7, 5))
plt.barh(*zip(*words_bigram_opinion))

plt.show()

# %%
# Se ve cuales son las palabras mas frecuentes en la category == opinion
sum_bigram_news = cv_bigram.fit_transform(df_news['clean_content'].values.astype('U')).sum(axis=0)

# Calculamos 
words_bigram_news = [(word, sum_bigram_news[0, idx]) for word, idx in cv_bigram.vocabulary_.items()]
words_bigram_news = sorted(words_bigram_news, key = lambda x: x[1], reverse=True)[:20]

sns.set(font_scale=1)

plt.figure(figsize=(7, 5))
plt.barh(*zip(*words_bigram_news))

plt.show()

# %%
cv_trigram = CountVectorizer(ngram_range=(3, 3))

# Se ve cuales son las palabras mas frecuentes en la category == opinion
sum_trigram_opinion = cv_trigram.fit_transform(df_opinion['clean_content'].values.astype('U')).sum(axis=0)

# Calculamos 
words_trigram_opinion = [(word, sum_trigram_opinion[0, idx]) for word, idx in cv_trigram.vocabulary_.items()]
words_trigram_opinion = sorted(words_trigram_opinion, key = lambda x: x[1], reverse=True)[:20]

sns.set(font_scale=1)

plt.figure(figsize=(7, 5))
plt.barh(*zip(*words_trigram_opinion))

plt.show()

# %%
# Se ve cuales son las palabras mas frecuentes en la category == opinion
sum_trigram_news = cv_trigram.fit_transform(df_news['clean_content'].values.astype('U')).sum(axis=0)

# Calculamos 
words_trigram_news = [(word, sum_trigram_news[0, idx]) for word, idx in cv_trigram.vocabulary_.items()]
words_trigram_news = sorted(words_trigram_news, key = lambda x: x[1], reverse=True)[:20]

sns.set(font_scale=1)

plt.figure(figsize=(7, 5))
plt.barh(*zip(*words_trigram_news))

plt.show()

# %%
list_bigram_opinion = [x[0] for x in words_bigram_opinion]
list_bigram_news = [y[0] for y in words_bigram_news]

# %%
unique_bigram_opinion = [x for x in list_bigram_opinion if x not in list_bigram_news]
unique_bigram_news = [x for x in list_bigram_news if x not in list_bigram_opinion]

# %%
print(unique_bigram_opinion)
print(unique_bigram_news)
# Out:
# ['zacks rank', 'consensus estimate', 'year year', 'zacks consensus', 'year ago', 'long term', 'earnings esp', 'rank strong', 'earnings growth', 'carry zacks', 'strong buy', 'earnings per', 'third quarter', 'growth rate', 'second quarter']
# ['new york', 'last year', 'united state', 'chief executive', 'investing com', 'last week', 'interest rate', 'wall street', 'central bank', 'last month', 'dow jones', 'told reuters', 'federal reserve', 'rose percent', 'jones industrial']

# %% [markdown]
# # Conclusión
#
# En este estudio preliminar se observa
